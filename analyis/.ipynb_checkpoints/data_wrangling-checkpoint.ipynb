# %% [markdown]
# #### Data Wrangling

# %% [markdown]
# > Import libraries

# %%
# pandas 
import pandas as pd 
# dependency for reading excel
import xlrd
#maplotloib
# %matplotlib inline
import seaborn as sns# import xlrd
import matplotlib.pyplot as plt

# %% [markdown]
# > Load data into worksapce

# %%
data_path = '../datasets/raw/Week2_challenge_data_source.xlsx'

# %%
data = pd.read_excel(data_path)

# %%
data
# Out:
#                    Bearer Id               Start  Start ms  \
# 0       13114483460844900352 2019-04-04 12:01:18     770.0
# 1       13114483482878900224 2019-04-09 13:04:04     235.0
# 2       13114483484080500736 2019-04-09 17:42:11       1.0
# 3       13114483485442799616 2019-04-10 00:31:25     486.0
# 4       13114483499480700928 2019-04-12 20:10:23     565.0
# ...                      ...                 ...       ...
# 149996   7277825670196679680 2019-04-29 07:28:42     451.0
# 149997   7349883264234609664 2019-04-29 07:28:42     483.0
# 149998  13114483573367300096 2019-04-29 07:28:43     283.0
# 149999  13114483573367300096 2019-04-29 07:28:43     696.0
# 150000                                       NaT       NaN
#
#                        End  End ms  Dur. (ms)          IMSI  MSISDN/Number  \
# 0      2019-04-25 14:35:31   662.0  1823652.0  2.082014e+14   3.366496e+10
# 1      2019-04-25 08:15:48   606.0  1365104.0  2.082019e+14   3.368185e+10
# 2      2019-04-25 11:58:13   652.0  1361762.0  2.082003e+14   3.376063e+10
# 3      2019-04-25 07:36:35   171.0  1321509.0  2.082014e+14   3.375034e+10
# 4      2019-04-25 10:40:32   954.0  1089009.0  2.082014e+14   3.369980e+10
# ...                    ...     ...        ...           ...            ...
# 149996 2019-04-30 06:02:33   214.0    81230.0  2.082022e+14   3.365069e+10
# 149997 2019-04-30 10:41:33   187.0    97970.0  2.082019e+14   3.366345e+10
# 149998 2019-04-30 10:46:12   810.0    98249.0  2.082017e+14   3.362189e+10
# 149999 2019-04-30 10:40:34   327.0    97910.0  2.082021e+14   3.361962e+10
# 150000                 NaT     NaN        NaN           NaN            NaN
#
#                 IMEI Last Location Name  ...  Youtube DL (Bytes)  \
# 0       3.552121e+13   9164566995485190  ...        1.585461e+07
# 1       3.579401e+13            L77566A  ...        2.024740e+07
# 2       3.528151e+13            D42335A  ...        1.972566e+07
# 3       3.535661e+13            T21824A  ...        2.138812e+07
# 4       3.540701e+13            D88865A  ...        1.525938e+07
# ...              ...                ...  ...                 ...
# 149996  3.548311e+13            D20434A  ...        1.619167e+07
# 149997  3.566051e+13            D10223C  ...        1.387723e+07
# 149998  3.572121e+13            T51102A  ...        2.266051e+07
# 149999  8.618620e+13            L88342B  ...        8.817106e+06
# 150000           NaN                NaN  ...        1.163407e+07
#
#         Youtube UL (Bytes)  Netflix DL (Bytes)  Netflix UL (Bytes)  \
# 0             2.501332e+06        8.198936e+06        9.656251e+06
# 1             1.911173e+07        1.833841e+07        1.722713e+07
# 2             1.469958e+07        1.758779e+07        6.163408e+06
# 3             1.514664e+07        1.399465e+07        1.097942e+06
# 4             1.896287e+07        1.712458e+07        4.152180e+05
# ...                    ...                 ...                 ...
# 149996        1.176343e+07        1.788370e+07        1.967816e+07
# 149997        8.288284e+06        1.935015e+07        2.129315e+07
# 149998        1.855903e+06        9.963942e+06        5.065760e+06
# 149999        8.305402e+06        3.322253e+06        1.317259e+07
# 150000        1.100941e+07        1.162685e+07        1.100175e+07
#
#         Gaming DL (Bytes)  Gaming UL (Bytes)  Other DL (Bytes)  \
# 0            2.780823e+08       1.434415e+07      1.717444e+08
# 1            6.087501e+08       1.170709e+06      5.269042e+08
# 2            2.295846e+08       3.956300e+05      4.106926e+08
# 3            7.995382e+08       1.084972e+07      7.490399e+08
# 4            5.277072e+08       3.529801e+06      5.507095e+08
# ...                   ...                ...               ...
# 149996       5.266097e+08       9.197207e+06      3.264510e+06
# 149997       6.268931e+08       4.735033e+06      7.121804e+08
# 149998       5.535395e+08       1.339432e+07      1.211009e+08
# 149999       3.525370e+08       2.529475e+06      8.147131e+08
# 150000       4.220447e+08       8.288398e+06      4.211005e+08
#
#         Other UL (Bytes)  Total UL (Bytes)  Total DL (Bytes)
# 0           8.814393e+06        36749741.0       308879636.0
# 1           1.505514e+07        53800391.0       653384965.0
# 2           4.215763e+06        27883638.0       279807335.0
# 3           1.279728e+07        43324218.0       846028530.0
# 4           1.391032e+07        38542814.0       569138589.0
# ...                  ...               ...               ...
# 149996      1.348742e+07        57628851.0       574175259.0
# 149997      2.457758e+06        39135081.0       666648844.0
# 149998      1.131473e+07        34912224.0       592786405.0
# 149999      1.406930e+06        29626096.0       371895920.0
# 150000      8.264799e+06               NaN               NaN
#
# [150001 rows x 55 columns]

# %% [markdown]
# #### Understanding the Data
#
# > Examins data for quality and strutural issues

# %% [markdown]
# > Data Info

# %%
print(f'Data Shape:\nColumns = {data.shape[0]}\nRows   =  {data.shape[1]}\n')
# Out:
# Data Shape:
# Columns = 150001
# Rows   =  55

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 150001 non-null  object
#  1   Start                                     150000 non-null  datetime64[ns]
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  datetime64[ns]
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
#  10  Avg RTT DL (ms)                           122172 non-null  float64
#  11  Avg RTT UL (ms)                           122189 non-null  float64
#  12  Avg Bearer TP DL (kbps)                   150000 non-null  float64
#  13  Avg Bearer TP UL (kbps)                   150000 non-null  float64
#  14  TCP DL Retrans. Vol (Bytes)               61855 non-null   float64
#  15  TCP UL Retrans. Vol (Bytes)               53352 non-null   float64
#  16  DL TP < 50 Kbps (%)                       149247 non-null  float64
#  17  50 Kbps < DL TP < 250 Kbps (%)            149247 non-null  float64
#  18  250 Kbps < DL TP < 1 Mbps (%)             149247 non-null  float64
#  19  DL TP > 1 Mbps (%)                        149247 non-null  float64
#  20  UL TP < 10 Kbps (%)                       149209 non-null  float64
#  21  10 Kbps < UL TP < 50 Kbps (%)             149209 non-null  float64
#  22  50 Kbps < UL TP < 300 Kbps (%)            149209 non-null  float64
#  23  UL TP > 300 Kbps (%)                      149209 non-null  float64
#  24  HTTP DL (Bytes)                           68527 non-null   float64
#  25  HTTP UL (Bytes)                           68191 non-null   float64
#  26  Activity Duration DL (ms)                 150000 non-null  float64
#  27  Activity Duration UL (ms)                 150000 non-null  float64
#  28  Dur. (ms).1                               150000 non-null  float64
#  29  Handset Manufacturer                      149429 non-null  object
#  30  Handset Type                              149429 non-null  object
#  31  Nb of sec with 125000B < Vol DL           52463 non-null   float64
#  32  Nb of sec with 1250B < Vol UL < 6250B     57107 non-null   float64
#  33  Nb of sec with 31250B < Vol DL < 125000B  56415 non-null   float64
#  34  Nb of sec with 37500B < Vol UL            19747 non-null   float64
#  35  Nb of sec with 6250B < Vol DL < 31250B    61684 non-null   float64
#  36  Nb of sec with 6250B < Vol UL < 37500B    38158 non-null   float64
#  37  Nb of sec with Vol DL < 6250B             149246 non-null  float64
#  38  Nb of sec with Vol UL < 1250B             149208 non-null  float64
#  39  Social Media DL (Bytes)                   150001 non-null  float64
#  40  Social Media UL (Bytes)                   150001 non-null  float64
#  41  Google DL (Bytes)                         150001 non-null  float64
#  42  Google UL (Bytes)                         150001 non-null  float64
#  43  Email DL (Bytes)                          150001 non-null  float64
#  44  Email UL (Bytes)                          150001 non-null  float64
#  45  Youtube DL (Bytes)                        150001 non-null  float64
#  46  Youtube UL (Bytes)                        150001 non-null  float64
#  47  Netflix DL (Bytes)                        150001 non-null  float64
#  48  Netflix UL (Bytes)                        150001 non-null  float64
#  49  Gaming DL (Bytes)                         150001 non-null  float64
#  50  Gaming UL (Bytes)                         150001 non-null  float64
#  51  Other DL (Bytes)                          150001 non-null  float64
#  52  Other UL (Bytes)                          150001 non-null  float64
#  53  Total UL (Bytes)                          150000 non-null  float64
#  54  Total DL (Bytes)                          150000 non-null  float64
# dtypes: datetime64[ns](2), float64(49), object(4)
# memory usage: 62.9+ MB

# %% [markdown]
# - It appears there are missing values in our dataset
# - We need to know what columns contain missing values, the number of these columns and find how to take care of it

# %% [markdown]
# > no of columns with missing values

# %%
f'no of columns with mssing values: {len(data.columns[data.isnull().any()].tolist())}'
# Out:
# 'no of columns with mssing values: 40'

# %% [markdown]
# > columns with missing values

# %%
null_cols = data.columns[data.isnull().any()].tolist()
null_cols
# Out:
# ['Start',
#  'Start ms',
#  'End',
#  'End ms',
#  'Dur. (ms)',
#  'IMSI',
#  'MSISDN/Number',
#  'IMEI',
#  'Last Location Name',
#  'Avg RTT DL (ms)',
#  'Avg RTT UL (ms)',
#  'Avg Bearer TP DL (kbps)',
#  'Avg Bearer TP UL (kbps)',
#  'TCP DL Retrans. Vol (Bytes)',
#  'TCP UL Retrans. Vol (Bytes)',
#  'DL TP < 50 Kbps (%)',
#  '50 Kbps < DL TP < 250 Kbps (%)',
#  '250 Kbps < DL TP < 1 Mbps (%)',
#  'DL TP > 1 Mbps (%)',
#  'UL TP < 10 Kbps (%)',
#  '10 Kbps < UL TP < 50 Kbps (%)',
#  '50 Kbps < UL TP < 300 Kbps (%)',
#  'UL TP > 300 Kbps (%)',
#  'HTTP DL (Bytes)',
#  'HTTP UL (Bytes)',
#  'Activity Duration DL (ms)',
#  'Activity Duration UL (ms)',
#  'Dur. (ms).1',
#  'Handset Manufacturer',
#  'Handset Type',
#  'Nb of sec with 125000B < Vol DL',
#  'Nb of sec with 1250B < Vol UL < 6250B',
#  'Nb of sec with 31250B < Vol DL < 125000B',
#  'Nb of sec with 37500B < Vol UL',
#  'Nb of sec with 6250B < Vol DL < 31250B',
#  'Nb of sec with 6250B < Vol UL < 37500B',
#  'Nb of sec with Vol DL < 6250B',
#  'Nb of sec with Vol UL < 1250B',
#  'Total UL (Bytes)',
#  'Total DL (Bytes)']

# %% [markdown]
# > poportion of null values in columns containtnig values

# %%
data[null_cols].isnull().mean()*100
# Out:
# Start                                        0.000667
# Start ms                                     0.000667
# End                                          0.000667
# End ms                                       0.000667
# Dur. (ms)                                    0.000667
# IMSI                                         0.379997
# MSISDN/Number                                0.710662
# IMEI                                         0.381331
# Last Location Name                           0.768662
# Avg RTT DL (ms)                             18.552543
# Avg RTT UL (ms)                             18.541210
# Avg Bearer TP DL (kbps)                      0.000667
# Avg Bearer TP UL (kbps)                      0.000667
# TCP DL Retrans. Vol (Bytes)                 58.763608
# TCP UL Retrans. Vol (Bytes)                 64.432237
# DL TP < 50 Kbps (%)                          0.502663
# 50 Kbps < DL TP < 250 Kbps (%)               0.502663
# 250 Kbps < DL TP < 1 Mbps (%)                0.502663
# DL TP > 1 Mbps (%)                           0.502663
# UL TP < 10 Kbps (%)                          0.527996
# 10 Kbps < UL TP < 50 Kbps (%)                0.527996
# 50 Kbps < UL TP < 300 Kbps (%)               0.527996
# UL TP > 300 Kbps (%)                         0.527996
# HTTP DL (Bytes)                             54.315638
# HTTP UL (Bytes)                             54.539636
# Activity Duration DL (ms)                    0.000667
# Activity Duration UL (ms)                    0.000667
# Dur. (ms).1                                  0.000667
# Handset Manufacturer                         0.381331
# Handset Type                                 0.381331
# Nb of sec with 125000B < Vol DL             65.024900
# Nb of sec with 1250B < Vol UL < 6250B       61.928920
# Nb of sec with 31250B < Vol DL < 125000B    62.390251
# Nb of sec with 37500B < Vol UL              86.835421
# Nb of sec with 6250B < Vol DL < 31250B      58.877607
# Nb of sec with 6250B < Vol UL < 37500B      74.561503
# Nb of sec with Vol DL < 6250B                0.503330
# Nb of sec with Vol UL < 1250B                0.528663
# Total UL (Bytes)                             0.000667
# Total DL (Bytes)                             0.000667
# dtype: float64

# %%
# data.isnull().mean()*100

# %% [markdown]
# > duplicated values in our rows

# %%
data.duplicated().any()
# Out:
# False

# %% [markdown]
# there are no duplicated rows

# %% [markdown]
# > Detecting Outliers in null columns
#
# This would help determine whether to impute null values using medain or mean

# %% [markdown]
# we would select all  numeric null columns and calcualate thier z-score to determine
#
# this would help us understand better hwo to impute the null values

# %%
numeric_data = data[null_cols]

# %%
numeric_data = numeric_data.select_dtypes(include="number")

# %% [markdown]
# We have to drop incorrect numeric datatype such as IMSI, IMEI.. this would be dealt with in the cleaning phase

# %%
numeric_data=numeric_data.drop(columns=['IMSI','IMEI','MSISDN/Number'], axis=1)#,inplace=True)

# %%
numeric_data
# Out:
#         Start ms  End ms  Dur. (ms)  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# 0          770.0   662.0  1823652.0             42.0              5.0
# 1          235.0   606.0  1365104.0             65.0              5.0
# 2            1.0   652.0  1361762.0              NaN              NaN
# 3          486.0   171.0  1321509.0              NaN              NaN
# 4          565.0   954.0  1089009.0              NaN              NaN
# ...          ...     ...        ...              ...              ...
# 149996     451.0   214.0    81230.0             32.0              0.0
# 149997     483.0   187.0    97970.0             27.0              2.0
# 149998     283.0   810.0    98249.0             43.0              6.0
# 149999     696.0   327.0    97910.0             37.0              5.0
# 150000       NaN     NaN        NaN              NaN              NaN
#
#         Avg Bearer TP DL (kbps)  Avg Bearer TP UL (kbps)  \
# 0                          23.0                     44.0
# 1                          16.0                     26.0
# 2                           6.0                      9.0
# 3                          44.0                     44.0
# 4                           6.0                      9.0
# ...                         ...                      ...
# 149996                     52.0                     65.0
# 149997                     23.0                     54.0
# 149998                     43.0                     47.0
# 149999                     34.0                     37.0
# 150000                      NaN                      NaN
#
#         TCP DL Retrans. Vol (Bytes)  TCP UL Retrans. Vol (Bytes)  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 149996                          NaN                          NaN
# 149997                          NaN                          NaN
# 149998                          NaN                          NaN
# 149999                          NaN                          NaN
# 150000                          NaN                          NaN
#
#         DL TP < 50 Kbps (%)  ...  Nb of sec with 125000B < Vol DL  \
# 0                     100.0  ...                              NaN
# 1                     100.0  ...                              NaN
# 2                     100.0  ...                              NaN
# 3                     100.0  ...                              NaN
# 4                     100.0  ...                              NaN
# ...                     ...  ...                              ...
# 149996                100.0  ...                              NaN
# 149997                100.0  ...                              NaN
# 149998                100.0  ...                              NaN
# 149999                100.0  ...                              NaN
# 150000                  NaN  ...                              NaN
#
#         Nb of sec with 1250B < Vol UL < 6250B  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 149996                                    NaN
# 149997                                    NaN
# 149998                                    NaN
# 149999                                    NaN
# 150000                                    NaN
#
#         Nb of sec with 31250B < Vol DL < 125000B  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 149996                                       NaN
# 149997                                       NaN
# 149998                                       NaN
# 149999                                       NaN
# 150000                                       NaN
#
#         Nb of sec with 37500B < Vol UL  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 149996                             NaN
# 149997                             NaN
# 149998                             NaN
# 149999                             NaN
# 150000                             NaN
#
#         Nb of sec with 6250B < Vol DL < 31250B  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 149996                                     NaN
# 149997                                     NaN
# 149998                                     NaN
# 149999                                     NaN
# 150000                                     NaN
#
#         Nb of sec with 6250B < Vol UL < 37500B  Nb of sec with Vol DL < 6250B  \
# 0                                          NaN                          213.0
# 1                                          NaN                          971.0
# 2                                          NaN                          751.0
# 3                                          NaN                           17.0
# 4                                          NaN                          607.0
# ...                                        ...                            ...
# 149996                                     NaN                          223.0
# 149997                                     NaN                          105.0
# 149998                                     NaN                          104.0
# 149999                                     NaN                           43.0
# 150000                                     NaN                            NaN
#
#         Nb of sec with Vol UL < 1250B  Total UL (Bytes)  Total DL (Bytes)
# 0                               214.0        36749741.0       308879636.0
# 1                              1022.0        53800391.0       653384965.0
# 2                               695.0        27883638.0       279807335.0
# 3                               207.0        43324218.0       846028530.0
# 4                               604.0        38542814.0       569138589.0
# ...                               ...               ...               ...
# 149996                          229.0        57628851.0       574175259.0
# 149997                          102.0        39135081.0       666648844.0
# 149998                          108.0        34912224.0       592786405.0
# 149999                           82.0        29626096.0       371895920.0
# 150000                            NaN               NaN               NaN
#
# [150001 rows x 32 columns]

# %%
numeric_data.dtypes
# Out:
# Start ms                                    float64
# End ms                                      float64
# Dur. (ms)                                   float64
# Avg RTT DL (ms)                             float64
# Avg RTT UL (ms)                             float64
# Avg Bearer TP DL (kbps)                     float64
# Avg Bearer TP UL (kbps)                     float64
# TCP DL Retrans. Vol (Bytes)                 float64
# TCP UL Retrans. Vol (Bytes)                 float64
# DL TP < 50 Kbps (%)                         float64
# 50 Kbps < DL TP < 250 Kbps (%)              float64
# 250 Kbps < DL TP < 1 Mbps (%)               float64
# DL TP > 1 Mbps (%)                          float64
# UL TP < 10 Kbps (%)                         float64
# 10 Kbps < UL TP < 50 Kbps (%)               float64
# 50 Kbps < UL TP < 300 Kbps (%)              float64
# UL TP > 300 Kbps (%)                        float64
# HTTP DL (Bytes)                             float64
# HTTP UL (Bytes)                             float64
# Activity Duration DL (ms)                   float64
# Activity Duration UL (ms)                   float64
# Dur. (ms).1                                 float64
# Nb of sec with 125000B < Vol DL             float64
# Nb of sec with 1250B < Vol UL < 6250B       float64
# Nb of sec with 31250B < Vol DL < 125000B    float64
# Nb of sec with 37500B < Vol UL              float64
# Nb of sec with 6250B < Vol DL < 31250B      float64
# Nb of sec with 6250B < Vol UL < 37500B      float64
# Nb of sec with Vol DL < 6250B               float64
# Nb of sec with Vol UL < 1250B               float64
# Total UL (Bytes)                            float64
# Total DL (Bytes)                            float64
# dtype: object

# %% [markdown]
# > We would etect outliers in each fo the column by calculating thier Z-Score

# %%
cols = list(numeric_data.columns)
outliers = pd.DataFrame()
#now iterate over the remaining columns and create a new zscore column
for col in cols:
    col_zscore = col + '_zscore'
    outliers[col_zscore] = (numeric_data[col] - numeric_data[col].mean())/numeric_data[col].std(ddof=0)

# %%
outliers
# Out:
#         Start ms_zscore  End ms_zscore  Dur. (ms)_zscore  \
# 0              0.938328       0.566473         21.212977
# 1             -0.915379       0.372094         15.554499
# 2             -1.726159       0.531763         15.513259
# 3             -0.045695      -1.137815         15.016538
# 4              0.228030       1.580022         12.147490
# ...                 ...            ...               ...
# 149996        -0.166966      -0.988560         -0.288491
# 149997        -0.056090      -1.082279         -0.081920
# 149998        -0.749065       1.080190         -0.078477
# 149999         0.681928      -0.596331         -0.082660
# 150000              NaN            NaN               NaN
#
#         Avg RTT DL (ms)_zscore  Avg RTT UL (ms)_zscore  \
# 0                    -0.109387               -0.149338
# 1                    -0.072277               -0.149338
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ...                        ...                     ...
# 149996               -0.125521               -0.208305
# 149997               -0.133589               -0.184719
# 149998               -0.107773               -0.137545
# 149999               -0.117454               -0.149338
# 150000                     NaN                     NaN
#
#         Avg Bearer TP DL (kbps)_zscore  Avg Bearer TP UL (kbps)_zscore  \
# 0                            -0.553861                       -0.373254
# 1                            -0.554153                       -0.377146
# 2                            -0.554570                       -0.380821
# 3                            -0.552985                       -0.373254
# 4                            -0.554570                       -0.380821
# ...                                ...                             ...
# 149996                       -0.552651                       -0.368714
# 149997                       -0.553861                       -0.371092
# 149998                       -0.553027                       -0.372606
# 149999                       -0.553402                       -0.374768
# 150000                             NaN                             NaN
#
#         TCP DL Retrans. Vol (Bytes)_zscore  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 149996                                 NaN
# 149997                                 NaN
# 149998                                 NaN
# 149999                                 NaN
# 150000                                 NaN
#
#         TCP UL Retrans. Vol (Bytes)_zscore  DL TP < 50 Kbps (%)_zscore  ...  \
# 0                                      NaN                      0.5488  ...
# 1                                      NaN                      0.5488  ...
# 2                                      NaN                      0.5488  ...
# 3                                      NaN                      0.5488  ...
# 4                                      NaN                      0.5488  ...
# ...                                    ...                         ...  ...
# 149996                                 NaN                      0.5488  ...
# 149997                                 NaN                      0.5488  ...
# 149998                                 NaN                      0.5488  ...
# 149999                                 NaN                      0.5488  ...
# 150000                                 NaN                         NaN  ...
#
#         Nb of sec with 125000B < Vol DL_zscore  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 149996                                     NaN
# 149997                                     NaN
# 149998                                     NaN
# 149999                                     NaN
# 150000                                     NaN
#
#         Nb of sec with 1250B < Vol UL < 6250B_zscore  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 149996                                           NaN
# 149997                                           NaN
# 149998                                           NaN
# 149999                                           NaN
# 150000                                           NaN
#
#         Nb of sec with 31250B < Vol DL < 125000B_zscore  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 149996                                              NaN
# 149997                                              NaN
# 149998                                              NaN
# 149999                                              NaN
# 150000                                              NaN
#
#         Nb of sec with 37500B < Vol UL_zscore  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 149996                                    NaN
# 149997                                    NaN
# 149998                                    NaN
# 149999                                    NaN
# 150000                                    NaN
#
#         Nb of sec with 6250B < Vol DL < 31250B_zscore  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 149996                                            NaN
# 149997                                            NaN
# 149998                                            NaN
# 149999                                            NaN
# 150000                                            NaN
#
#         Nb of sec with 6250B < Vol UL < 37500B_zscore  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 149996                                            NaN
# 149997                                            NaN
# 149998                                            NaN
# 149999                                            NaN
# 150000                                            NaN
#
#         Nb of sec with Vol DL < 6250B_zscore  \
# 0                                  -0.382354
# 1                                  -0.299707
# 2                                  -0.323694
# 3                                  -0.403724
# 4                                  -0.339395
# ...                                      ...
# 149996                             -0.381263
# 149997                             -0.394129
# 149998                             -0.394238
# 149999                             -0.400889
# 150000                                   NaN
#
#         Nb of sec with Vol UL < 1250B_zscore  Total UL (Bytes)_zscore  \
# 0                                  -0.374801                -0.387667
# 1                                  -0.295275                 1.124405
# 2                                  -0.327459                -1.173923
# 3                                  -0.375490                 0.195366
# 4                                  -0.336416                -0.228655
# ...                                      ...                      ...
# 149996                             -0.373324                 1.463918
# 149997                             -0.385824                -0.176132
# 149998                             -0.385233                -0.550620
# 149999                             -0.387792                -1.019400
# 150000                                   NaN                      NaN
#
#         Total DL (Bytes)_zscore
# 0                     -0.597045
# 1                      0.814041
# 2                     -0.716124
# 3                      1.603104
# 4                      0.468969
# ...                         ...
# 149996                 0.489599
# 149997                 0.868369
# 149998                 0.565830
# 149999                -0.338932
# 150000                      NaN
#
# [150001 rows x 32 columns]

# %% [markdown]
# #### values with __Z-score >=3 & Z-score <=-3__ are outliers.
#
#  - If the frequency of such values are larger than 40% in any column, we would condier such column as having large number of outliers
#
# - Null columns with outliers greater than 40% would be imputed using median
#
# - Null columns with outliers less than 40% would be imputed using mean

# %%
def z_prop(df, col_list):
    z_dict = {}
    for col in col_list:
#         origcol_size = df[col].shape[0]
        zs = df[(df[col] >=3) | (df[col]<=-3)]
        #display(zs)
        print(f'{col}  -   {zs.shape[0]}')
        prop = round((zs.shape[0]/df.shape[0])*100,2)
        z_dict[col] = prop
    return z_dict

# %%
outlier_prop = z_prop(outliers, outliers.columns.to_list())
# Out:
# Start ms_zscore  -   0
# End ms_zscore  -   0
# Dur. (ms)_zscore  -   2214
# Avg RTT DL (ms)_zscore  -   717
# Avg RTT UL (ms)_zscore  -   677
# Avg Bearer TP DL (kbps)_zscore  -   2983
# Avg Bearer TP UL (kbps)_zscore  -   4269
# TCP DL Retrans. Vol (Bytes)_zscore  -   416
# TCP UL Retrans. Vol (Bytes)_zscore  -   55
# DL TP < 50 Kbps (%)_zscore  -   3467
# 50 Kbps < DL TP < 250 Kbps (%)_zscore  -   3462
# 250 Kbps < DL TP < 1 Mbps (%)_zscore  -   3147
# DL TP > 1 Mbps (%)_zscore  -   3464
# UL TP < 10 Kbps (%)_zscore  -   2199
# 10 Kbps < UL TP < 50 Kbps (%)_zscore  -   2018
# 50 Kbps < UL TP < 300 Kbps (%)_zscore  -   1029
# UL TP > 300 Kbps (%)_zscore  -   749
# HTTP DL (Bytes)_zscore  -   314
# HTTP UL (Bytes)_zscore  -   394
# Activity Duration DL (ms)_zscore  -   3558
# Activity Duration UL (ms)_zscore  -   2958
# Dur. (ms).1_zscore  -   2214
# Nb of sec with 125000B < Vol DL_zscore  -   1122
# Nb of sec with 1250B < Vol UL < 6250B_zscore  -   616
# Nb of sec with 31250B < Vol DL < 125000B_zscore  -   1129
# Nb of sec with 37500B < Vol UL_zscore  -   130
# Nb of sec with 6250B < Vol DL < 31250B_zscore  -   1044
# Nb of sec with 6250B < Vol UL < 37500B_zscore  -   346
# Nb of sec with Vol DL < 6250B_zscore  -   2995
# Nb of sec with Vol UL < 1250B_zscore  -   3685
# Total UL (Bytes)_zscore  -   55
# Total DL (Bytes)_zscore  -   0

# %% [markdown]
# #### Proportion of outliers values in each column

# %%
outlier_prop
# Out:
# {'Start ms_zscore': 0.0,
#  'End ms_zscore': 0.0,
#  'Dur. (ms)_zscore': 1.48,
#  'Avg RTT DL (ms)_zscore': 0.48,
#  'Avg RTT UL (ms)_zscore': 0.45,
#  'Avg Bearer TP DL (kbps)_zscore': 1.99,
#  'Avg Bearer TP UL (kbps)_zscore': 2.85,
#  'TCP DL Retrans. Vol (Bytes)_zscore': 0.28,
#  'TCP UL Retrans. Vol (Bytes)_zscore': 0.04,
#  'DL TP < 50 Kbps (%)_zscore': 2.31,
#  '50 Kbps < DL TP < 250 Kbps (%)_zscore': 2.31,
#  '250 Kbps < DL TP < 1 Mbps (%)_zscore': 2.1,
#  'DL TP > 1 Mbps (%)_zscore': 2.31,
#  'UL TP < 10 Kbps (%)_zscore': 1.47,
#  '10 Kbps < UL TP < 50 Kbps (%)_zscore': 1.35,
#  '50 Kbps < UL TP < 300 Kbps (%)_zscore': 0.69,
#  'UL TP > 300 Kbps (%)_zscore': 0.5,
#  'HTTP DL (Bytes)_zscore': 0.21,
#  'HTTP UL (Bytes)_zscore': 0.26,
#  'Activity Duration DL (ms)_zscore': 2.37,
#  'Activity Duration UL (ms)_zscore': 1.97,
#  'Dur. (ms).1_zscore': 1.48,
#  'Nb of sec with 125000B < Vol DL_zscore': 0.75,
#  'Nb of sec with 1250B < Vol UL < 6250B_zscore': 0.41,
#  'Nb of sec with 31250B < Vol DL < 125000B_zscore': 0.75,
#  'Nb of sec with 37500B < Vol UL_zscore': 0.09,
#  'Nb of sec with 6250B < Vol DL < 31250B_zscore': 0.7,
#  'Nb of sec with 6250B < Vol UL < 37500B_zscore': 0.23,
#  'Nb of sec with Vol DL < 6250B_zscore': 2.0,
#  'Nb of sec with Vol UL < 1250B_zscore': 2.46,
#  'Total UL (Bytes)_zscore': 0.04,
#  'Total DL (Bytes)_zscore': 0.0}

# %%
outlier_df = pd.Series(outlier_prop).reset_index()
outlier_df.rename(columns={'index':'features',0:'prop_outliers'}, inplace=True)

# %%
outlier_df
# Out:
#                                            features  prop_outliers
# 0                                   Start ms_zscore           0.00
# 1                                     End ms_zscore           0.00
# 2                                  Dur. (ms)_zscore           1.48
# 3                            Avg RTT DL (ms)_zscore           0.48
# 4                            Avg RTT UL (ms)_zscore           0.45
# 5                    Avg Bearer TP DL (kbps)_zscore           1.99
# 6                    Avg Bearer TP UL (kbps)_zscore           2.85
# 7                TCP DL Retrans. Vol (Bytes)_zscore           0.28
# 8                TCP UL Retrans. Vol (Bytes)_zscore           0.04
# 9                        DL TP < 50 Kbps (%)_zscore           2.31
# 10            50 Kbps < DL TP < 250 Kbps (%)_zscore           2.31
# 11             250 Kbps < DL TP < 1 Mbps (%)_zscore           2.10
# 12                        DL TP > 1 Mbps (%)_zscore           2.31
# 13                       UL TP < 10 Kbps (%)_zscore           1.47
# 14             10 Kbps < UL TP < 50 Kbps (%)_zscore           1.35
# 15            50 Kbps < UL TP < 300 Kbps (%)_zscore           0.69
# 16                      UL TP > 300 Kbps (%)_zscore           0.50
# 17                           HTTP DL (Bytes)_zscore           0.21
# 18                           HTTP UL (Bytes)_zscore           0.26
# 19                 Activity Duration DL (ms)_zscore           2.37
# 20                 Activity Duration UL (ms)_zscore           1.97
# 21                               Dur. (ms).1_zscore           1.48
# 22           Nb of sec with 125000B < Vol DL_zscore           0.75
# 23     Nb of sec with 1250B < Vol UL < 6250B_zscore           0.41
# 24  Nb of sec with 31250B < Vol DL < 125000B_zscore           0.75
# 25            Nb of sec with 37500B < Vol UL_zscore           0.09
# 26    Nb of sec with 6250B < Vol DL < 31250B_zscore           0.70
# 27    Nb of sec with 6250B < Vol UL < 37500B_zscore           0.23
# 28             Nb of sec with Vol DL < 6250B_zscore           2.00
# 29             Nb of sec with Vol UL < 1250B_zscore           2.46
# 30                          Total UL (Bytes)_zscore           0.04
# 31                          Total DL (Bytes)_zscore           0.00

# %%
outlier_df.prop_outliers.unique()
# Out:
# array([0.  , 1.48, 0.48, 0.45, 1.99, 2.85, 0.28, 0.04, 2.31, 2.1 , 1.47,
#        1.35, 0.69, 0.5 , 0.21, 0.26, 2.37, 1.97, 0.75, 0.41, 0.09, 0.7 ,
#        0.23, 2.  , 2.46])

# %% [markdown]
# ##### None of our null columns have outlier values greater than 40% of normal values
#
# - hence we would impute null values in this column using the mean, as we have some confidence that these outlier values would not greatly affect the mean

# %% [markdown]
# #### Inspect categorical columns for formatting consistency
#
# > specifically 'handset_type and handset_manufacturer'

# %%
data[ 'Handset Manufacturer'].unique()
# Out:
# array(['Samsung', 'undefined', 'Huawei', 'Apple', 'Zte',
#        'TP-Link Technologies Co Ltd', 'Ertebat Hamrah Guya Arvand',
#        'Wiko Global Sasu', 'TCL Communication Ltd',
#        'Oneplus Technology (Shenzhen) Co Ltd', nan,
#        'Zebra Technologies Corp.', 'Nokia', 'Wiko',
#        'Tcl Communication Ltd', 'ZTE', 'Lenovo', 'Asustek',
#        'Xiaomi Communications Co Ltd', 'Rim', 'Hmd Global Oy',
#        'Sony Mobile Communications AB', 'D-Link Corporation', 'Wct',
#        'Dn Electronics', 'Sony Mobile Communications Ab', 'Netgear Inc',
#        'Neel Enterprise', 'Teletalk Pvt Ltd', 'DDM Brands LLC',
#        'Tp-Link Technologies Co Ltd', 'Sierra Wireless', 'Google Inc',
#        'Shenzhen Chainway Information Technology Co Ltd',
#        'Microsoft Mobile Oy', 'Htc', 'Crosscall',
#        'Shenzhen Kdi Communication Co Ltd',
#        'Simcom Wireless Solutions Co Ltd',
#        'Qingdao Hisense Communications Co Ltd', 'Lg', 'Archos Sa',
#        'Hewlett-Packard', 'Spa Condor Electronics',
#        'Sonaki Corporation S.A.', 'New-Bund Technology Co Limited',
#        'Meizu Technology Co Ltd', 'LG', 'Doro Ab',
#        'Shenzhen Jeko Communication Co Limited',
#        'Vivo Mobile Communication Co Ltd', 'Gemalto M2M Gmbh',
#        'Maysun Info Technology Co Ltd',
#        'Shenzhen Fortuneship Technology Co Ltd', 'RIM',
#        'Shenzhen Leagoo Intelligence Co Ltd', 'Yota Devices',
#        'Electro Depot France Sas', 'Source (Hk) Ltd', 'Oppo',
#        'Logicom Sa', 'Infocus Corporation', 'Sony Ericsson',
#        'Tct Mobile Suzhou Limited', 'Acer', 'Lephone',
#        'Concox Information Technology (Hong Kong) Co Ltd',
#        'Wileyfox Europe Limited', 'ASUSTeK',
#        'Shenzhen Xin Kingbrand Technology Development Co Ltd',
#        'Kvd International Group Limited', 'China Trade Group S.A.S',
#        'Archos SA', 'Hem', 'Kapsys',
#        'Vplus Communication Technology Co Limited',
#        'Intermec Technologies', 'Tinno Mobile Technology Copr',
#        'Fairphone B.V', 'Doke Communication (Hk) Limited',
#        'Lemobile Information Technology (Beijing) Co Ltd',
#        'Shenzhen Boway Electronic Co Ltd',
#        'Rainbow Communication (Private) Limited',
#        'TCT Mobile Suzhou Limited', 'Dg Homtom Group Co Limited',
#        'Shenzhen Huanuo Internet Technology Co Ltd', 'Orbita Telecom Ltd',
#        'Hong Kong Frog International Limited', 'Kiwip Technologies Sas',
#        'Kook (Hong Kong) Technology Limited', 'Sfr', 'Kenxinda',
#        'Mundo Reader S.L.', 'Umi Network Technology Co Limited',
#        'Nubia Technology Co Ltd', 'Avenir Telecom',
#        'Shanghai Chengyu Media Technology Co Ltd', 'SFR',
#        'Bullitt Group Limited', 'Haier', 'HTC',
#        'Shenzhen New Chabridge Communication Co Ltd',
#        'Leagoo Intl Co. Limited', 'Fully Holdings (Hk) Co Limited',
#        'Doro AB', 'A-Link Telecom International Co Limited',
#        'Tecno Telecom (Hk) Limited', 'Alif Communications',
#        'Shenzhen Jsr Technology Co Ltd',
#        'Gotron (Hk) Electronic Co Limited', 'Ecom Instruments GmbH',
#        'Sdt Electronica', 'Infinix Technology Limited', 'Modelabs',
#        'Casper Bilgisayar Sistemleri A.S',
#        'Shenzhen Diadem Technology Co Ltd', 'Quartel Infotech Ltd',
#        'Hongkong Ipro Technology Co Limited',
#        'Shenzhen Guowei Electronics Co Ltd',
#        'Dynamic Tech Holdings Limited', 'Shenzhen Malata',
#        'Kazam Mobile Limited', 'Lidaxin Technology Limited',
#        'M S Soha Enterprise', 'Ddm Brands Llc', 'Quanta',
#        'Cisco Systems Inc (Including All Affiliates)',
#        'Zyxel Communications Corp', 'Adar', 'Compal Electronics Inc',
#        'Topwell Technology (HK) Company Limited', 'Wistron', 'Telit',
#        'Itel Technology Limited',
#        'Power Idea Technology (Shenzhen) Co Ltd', 'Mptech',
#        'KVD International Group Limited', 'Pt. Arga Mas Lestari',
#        'Group Acquisitions Limited', 'Gigaset Communications Gmbh',
#        'Vastking Technology (Hk) Limited', 'Mobiwire Sas', 'Option Nv',
#        'Shenzhen City Ramos Digital Technology Co Ltd',
#        'Sentar Wireless Technology Co Limited',
#        'Sintave Technology (Group) Co Ltd',
#        'Honstech Communication Co Ltd', 'Pacific Co (Bd) Ltd',
#        'Blu Products Inc', 'Yop Technology Co Limited', 'Bird', 'Tianyu',
#        'DN Electronics', 'Civicom Technology (Hk) Co Limited',
#        'Shenzhen Huadoo Bright Group Limited',
#        'Beijing Shenqi Technology Co Ltd', 'Essential Products Inc.',
#        'Sonim Technologies Inc', 'Ovvi-Cellphone Tech. Inc.',
#        'Quectel Wireless Solutions Co Ltd',
#        'Yi Sheng Technology International (Hk) Co Limited',
#        'Shenzhen Yiqingteng Electronic Technology Co Ltd',
#        'Shenzhen Sprocomm Technologies Co Ltd',
#        'ZyXEL Communications Corp', 'Razer Inc', 'Mikrotikls Sia',
#        'Tianlong International (Hk) Co Ltd',
#        'Shenzhen Kelly The Communication Equipment Co Ltd', 'Test IMEI',
#        'Ck Telecom Limited', 'Shenzhen Gaoxinqi'], dtype=object)

# %% [markdown]
# - We have same comapnies like (ZyXEL Communications Corp & Zyxel Communications Corp)
#
#  -- We have to make them have same fomatting

# %%
data['Handset Type'].unique().tolist()
# Out:
# ['Samsung Galaxy A5 Sm-A520F',
#  'Samsung Galaxy J5 (Sm-J530)',
#  'Samsung Galaxy A8 (2018)',
#  'undefined',
#  'Samsung Sm-G390F',
#  'Huawei Mate 20 Lite',
#  'Samsung Galaxy Note 8 (Sm-N950F Ds)',
#  'Huawei B593S-22',
#  'Samsung Galaxy J3 (Sm-J330)',
#  'Samsung Galaxy S8 (Sm-G950F)',
#  'Huawei E5180',
#  'Apple iPhone 6S (A1688)',
#  'Samsung Galaxy A3 (Sm-A320)',
#  'Huawei P20 Pro',
#  'Samsung Galaxy J7',
#  'Samsung Galaxy S7 (Sm-G930X)',
#  'Zte Mf259',
#  'Tp-Link Technolo. Tp-Link Archer Mr200 Tp-Link Tl-Mr6400',
#  'Samsung Galaxy S9 Sm-G960F Ds',
#  'Huawei B528S-23A',
#  'Huawei Mate 10 Pro Porsche Design Huawei Mate 10',
#  'Samsung Galaxy Note 8 (Sm-N950F)',
#  'Apple iPhone Se (A1723)',
#  'Apple iPhone 8 (A1905)',
#  'Samsung Galaxy S10',
#  'Apple iPhone 7 (A1778)',
#  'Samsung Galaxy S6 Edge (Sm-G925X)',
#  'Samsung Galaxy A6 Sm-A600Fn Ds',
#  'Apple iPhone 7 Plus (A1784)',
#  'Apple iPhone 6 (A1586)',
#  'Apple iPhone 6 Plus (A1524)',
#  'Apple iPhone Xr (A2105)',
#  'Samsung Galaxy S9 Plus (Sm-G965F)',
#  'Huawei Y6 2018',
#  'Huawei Stf-L09',
#  'Huawei Y7 2018',
#  'Apple iPad Pro 10.5 (A1709)',
#  'Huawei P20 Lite Huawei Nova 3E',
#  'Apple iPhone 6S Plus (A1687)',
#  'Apple iPhone Xs Max (A2101)',
#  'Samsung Galaxy S9',
#  'Apple iPhone 6S (A1633)',
#  'Apple iPhone 6 (A1549)',
#  'Apple iPhone 8 Plus (A1897)',
#  'Huawei Pot-Lx1',
#  'Samsung Galaxy S7 Edge (Sm-G935X)',
#  'Apple iPhone 7 (A1660)',
#  'Huawei P20',
#  'Samsung Galaxy S6 (Sm-G920X)',
#  'Ertebat Hamrah G. Glx H1',
#  'Apple iPhone X (A1901)',
#  'Apple iPhone 6S Plus (A1634)',
#  'Wiko Global Sasu Tommy3',
#  'Huawei Fig-Lx1',
#  'Huawei Honor 8X',
#  'Samsung Galaxy S8 Plus (Sm-G955F)',
#  'Huawei P9',
#  'Apple iPhone Xs Max (A1921)',
#  'Samsung Galaxy J6+',
#  'Apple iPhone Xs (A2097)',
#  'Samsung Galaxy A3 (Sm-A310X)',
#  'Apple iPhone 8 Plus (A1864)',
#  'Huawei P10',
#  'Huawei P8 Lite',
#  'Tcl Communicatio. Linkzone',
#  'Samsung Galaxy A6 (Sm-A605Fn)',
#  'Huawei Honor 9 Lite',
#  'Oneplus Technolo. Oneplus 6',
#  'Huawei Honor View10',
#  'Wiko Global Sasu Wiko Sunny',
#  'Huawei Lya-L29',
#  'Samsung Galaxy Note9',
#  nan,
#  'Wiko Global Sasu Harry2',
#  'Samsung Galaxy Trend Lite 2 (Sm-G318X)',
#  'Samsung Galaxy A5 (Sm-A500X)',
#  'Samsung Galaxy S3 Mini Ve(Gt-I8200X)',
#  'Zebra Technologi. Symbol Tc55Bh',
#  'Nokia 520 Lumia 520 Nokia 520',
#  'Apple iPhone 4 (A1332)',
#  'Wiko Jerry3',
#  'Apple iPad (A1954)',
#  'Huawei Y5Ii',
#  'Tcl Communicatio. Alcatel Pixi 4 (5) 5010D',
#  'Zte Blade A452 Blade A452',
#  'Lenovo Gl12494745',
#  'Tcl Communicatio. Alcatel Pixi 4 (4) 4034D',
#  'Asustek Asus Zb555Kl Zenfone Max M1',
#  'Apple iPhone 5 (A1429)',
#  'Wiko Global Sasu Sunny3',
#  'Samsung Galaxy A7 2018',
#  'Xiaomi Communica. Redmi Note5',
#  'Apple iPhone 4S (A1387)',
#  'Wiko Global Sasu View2 Go',
#  'Wiko Global Sasu Wiko View',
#  'Huawei Col-L29',
#  'Samsung Galaxy Note 2 (Gt-N7100)',
#  'Samsung Galaxy Grand Prime Ve (Sm-G531X)',
#  'Wiko Global Sasu Wiko Rainbow Lite 4G',
#  'Samsung Galaxy S4 Mini (Gt-I9195)',
#  'Samsung Galaxy J7 (Sm-J730)',
#  'Samsung Galaxy Trend Lite (Gt-S7390)',
#  'Wiko Global Sasu Wiko Lenny4',
#  'Apple iPhone 5S (A1457)',
#  'Samsung Sm-G350',
#  'Rim Blackberry Sqn100-3 Q10 Rfn81Uw',
#  'Huawei Y5 2018',
#  'Hmd Global Oy Ta-1006',
#  'Sony Mobile Comm. Sony Xperia M2',
#  'Nokia N8-00',
#  'Sony Mobile Comm. Xperia Z3 Compact',
#  'Xiaomi Communica. Redmi 3S',
#  'D-Link Corporati. D-Link Lte Usb Adaptor',
#  'Huawei E5573B',
#  'Wiko Global Sasu Wiko Freddy',
#  'Samsung Galaxy J3 (Sm-J320X)',
#  'Wct Uno',
#  'Samsung Galaxy S5 Mini (Sm-G800X)',
#  'Samsung Galaxy S2 (Gt-I9100)',
#  'Apple iPhone 6 Plus (A1522)',
#  'Apple iPhone 5C (A1507)',
#  'Asustek Asus Zenfone Max Plus Zb570Tl',
#  'Apple iPhone Se (A1662)',
#  'Dn Electronics Danew Konnect 350',
#  'Samsung Galaxy Grand (Gt-I9060X)',
#  'Huawei E5573',
#  'Apple iPad Pro (A1652)',
#  'Samsung Galaxy Grand Prime (Sm-G530F)',
#  'Huawei Dli-L22',
#  'Sony Mobile Comm. Xperia Xz2',
#  'Samsung Galaxy Note Edge (Sm-N915X)',
#  'Nokia Rm-1038 Nokia Lumia 735',
#  'Apple iPhone 7 (A1779)',
#  'Huawei B593',
#  'Samsung Galaxy S4 (Gt-I9505)',
#  'Netgear Inc Aircard 810S',
#  'Apple iPhone 5C (A1532)',
#  'Samsung Galaxy Grand Prime (Sm-G530X)',
#  'Wiko Global Sasu Wiko Jerry2',
#  'Samsung Galaxy J5 (Sm-J500X)',
#  'Huawei P9 Lite',
#  'Neel Enterprise Kolor Crosscalltrekker-X2',
#  'Samsung Galaxy J6',
#  'Teletalk Pvt Ltd Colors Cl220+',
#  'Huawei Ascend G620S',
#  'Samsung Galaxy J7 (Sm-J710X)',
#  'Asustek Asus Zenfone Go Zb500Kl',
#  'Sony Mobile Comm. Xperia Xa',
#  'Wiko Global Sasu Wiko Sunny2 Plus',
#  'Ddm Brands Llc Andy 5Ei3',
#  'Sony Mobile Comm. Xperia Xa1',
#  'Nokia 610 Nokia 610',
#  'Tp-Link Technolo. Tp-Link Tp701A',
#  'Lenovo Lenovo A Plus Lenovo Vibe A Plus',
#  'Samsung Galaxy Ace (Gt-S5839I)',
#  'Tp-Link Technolo. Archer Mr400',
#  'Sierra Wireless Hl6528Rd-2.8V',
#  'Google Inc Pixel 3',
#  'Wiko Global Sasu Lenny 5',
#  'Apple iPad Mini 4 (A1550)',
#  'Samsung Galaxy S5 Neo (Sm-G903)',
#  'Huawei Honor 5X',
#  'Huawei Y5',
#  'Sony Mobile Comm. Xperia Xa2 Ultra',
#  'Samsung Galaxy S5 Lte-A (Sm-G901X)',
#  'Huawei P10 Lite',
#  'Apple iPhone 7 Plus (A1661)',
#  'Shenzhen Chainwa. C70',
#  'Samsung Galaxy Y (Gt-S5360)',
#  'Nokia Rm-980 Nokia X',
#  'Huawei Hry-Lx1',
#  'Samsung Sm-J106H Ds',
#  'Samsung Sm-J250Y Ds',
#  'Asustek Asus Zenfone 4 Selfie Zd553Kl',
#  'Wiko Global Sasu Wiko Lenny3',
#  'Samsung Galaxy S6 Plus (Sm-G928)',
#  'Samsung Galaxy A3 (Sm-A300X)',
#  'Huawei E5186S',
#  'Samsung Galaxy Ace (Gt-S5830)',
#  'Huawei Y6 2017 Huawei Nova Young Huawei Y5 2017',
#  'Huawei B525S-23A',
#  'Samsung Galaxy J5 (Sm-J510X)',
#  'Microsoft Mobile. Microsoft Rm-1075 Microsoft Lumia 640 Lte Dual Sim',
#  'Sony Mobile Comm. Xperia Xa2',
#  'Sony Mobile Comm. Xperia Xz1',
#  'Huawei Y6 2017 Huawei Nova Young',
#  'Htc 10',
#  'Sony Mobile Comm. Xperia M4 Aqua',
#  'Samsung Galaxy Xcover4 Sm-G390F',
#  'Crosscall Trekker-M1 Core',
#  'Apple iPhone 8 (A1906)',
#  'Apple iPhone X (A1865)',
#  'Shenzhen Kdi Com. D58',
#  'Huawei E5372S-32',
#  'Tp-Link Technolo. Tl-Mr6400',
#  'Simcom Wireless. Sim900',
#  'Samsung Galaxy J7 (Sm-J700X)',
#  'Apple iPad Air (A1475)',
#  'Huawei Frd-L09',
#  'Samsung Galaxy S8 (Sm-G950Fd)',
#  'Tcl Communicatio. U3 3G',
#  'Samsung Sm-G389F',
#  'Samsung Galaxy Grand 2 (Sm-G7105)',
#  'Tcl Communicatio. Alcatel U5',
#  'Qingdao Hisense. Hs-U609 Hisense I500U Hisense E260U Hs-U607 Hs-U980 Pure 1 Eco',
#  'Microsoft Mobile. Nokia Lumia 630 Rm-976',
#  'Samsung Galaxy Tab Active Sm-T365',
#  'Wiko Global Sasu Wiko Sunset2',
#  'Lg Lg-T385',
#  'Huawei Ele-L29',
#  'Samsung Galaxy A6',
#  'Wiko Global Sasu Wiko Tommy',
#  'Sony Mobile Comm. Xperia L1',
#  'Nokia Rm-1017 530 Lumia 530',
#  'Tcl Communicatio. Alcatel Onetouch Pixi 3 (4)',
#  'Nokia Rm-1089 Lumia 535 Microsoft Lumia 535',
#  'Wiko Global Sasu View Max',
#  'Microsoft Mobile. Nokia Lumia 635 Rm-974',
#  'Wiko Global Sasu Fever',
#  'Wiko Global Sasu Jerry3',
#  'Samsung Sm-G357Fz',
#  'D-Link Corporati. Dwr-932',
#  'Sony Mobile Comm. Xperia Z3',
#  'Huawei Pct-L29',
#  'Huawei B715S-23C',
#  'Htc Desire 530',
#  'Microsoft Mobile. Rm-1090 Microsoft Lumia 535 Dual Sim',
#  'Wiko Global Sasu Wiko Darkmoon Slide',
#  'Huawei Mate 10 Lite Huawei Nova 2I',
#  'Samsung Galaxy J1 Mini (Sm-J105X)',
#  'D-Link Corporati. D-Link Dwr-921',
#  'Microsoft Mobile. Rm-1072 Microsoft Lumia 640 Lte',
#  'Samsung Galaxy S3 Mini (Gt-I8190)',
#  'Huawei Mate 9',
#  'Wiko Global Sasu Wiko Lenny2',
#  'Archos Sa 50 Saphir',
#  'Apple iPhone 6S (A1700)',
#  'Archos Sa 55B Platinum',
#  'Huawei Honor 6X',
#  'Samsung Xcover 3 (Sm-G388X)',
#  'Huawei Sne-Lx1',
#  'Hewlett-Packard Hp Elite X3',
#  'Apple iPhone 8 (A1863)',
#  'Spa Condor Elect. Allure M1',
#  'Microsoft Mobile. Nokia Rm-974 Nokia Lumia 635',
#  'Sony Mobile Comm. Xperia T3',
#  'Htc One',
#  'Huawei Lld-Al00',
#  'Htc Desire 510',
#  'Tcl Communicatio. Alcatel 1X',
#  'Huawei E5577',
#  'Xiaomi Communica. Redmi Note4',
#  'Samsung Galaxy S (Gt-I9000)',
#  'Lenovo K520',
#  'Sonaki Corporati. Crown Japan Cr-Mp3019',
#  'New-Bund Technol. Thor',
#  'Huawei Honor 10',
#  'Apple iPhone 5S (A1533)',
#  'Apple iPhone 5S (A1530)',
#  'Samsung Galaxy A7 (Sm-A700X)',
#  'Samsung Galaxy Note 4 (Sm-N910X)',
#  'Meizu Technology. M6 Note',
#  'Samsung Gt-C3590',
#  'Wiko Global Sasu Wiko Lenny4 Plus',
#  'Lg G6',
#  'Samsung Galaxy S5 (Sm-G900F)',
#  'Oneplus Technolo. Oneplus 6T',
#  'Asustek Asus Zenfone 3 Ze520Kl',
#  'Huawei Mrd-Lx1',
#  'Apple iPhone Xr (A1984)',
#  'Hmd Global Oy Ta-1063',
#  'Huawei Nexus 6P',
#  'Samsung Galaxy S5 (Sm-G900X)',
#  'Rim Blackberry 9720',
#  'Wiko Global Sasu Wiko Rainbow Getaway',
#  'Lg Nexus 5X',
#  'Huawei E5785Lh-22C',
#  'Lenovo Moto G (5Th Gen) Indr003546',
#  'Rim Pearl 8100',
#  'Samsung Galaxy S8 Plus (Sm-G955Fd)',
#  'Doro Ab Doro Liberto 822 Doro 8031',
#  'Asustek Asus Zenfone 4 Max Zc554Kl',
#  'Lg Nexus 4 (E960)',
#  'Sony Mobile Comm. Xperia X',
#  'Sony Mobile Comm. Xperia Z5 Compact',
#  'Wiko Global Sasu Wiko Pulp Fab 4G',
#  'Apple iPhone 5S (A1453)',
#  'Lg-H870Ds',
#  'Shenzhen Jeko Co. Blackview Bv5800',
#  'Wiko Global Sasu Wiko U Feel',
#  'Samsung Galaxy A5 (Sm-A510X)',
#  'Huawei Ine-Lx1',
#  'Huawei Tit-Al00 Huawei Y6 Pro',
#  'Vivo Mobile Comm. Vivo Vivo X7Plus',
#  'Samsung Galaxy S3 (Gt-I9305)',
#  'Samsung Galaxy J2 (Sm-J200X)',
#  'Gemalto M2M Gmbh Eu3-E',
#  'Samsung Galaxy Express Gt-I8730',
#  'Asustek Asus Zenfone 5 Ze620Kl',
#  'Oneplus Technolo. Oneplus 5T',
#  'Huawei Col-Al10',
#  'Sony Mobile Comm. Xperia Xa1 Ultra',
#  'Xiaomi Communica. Mi 8',
#  'Huawei Honor 7X',
#  'Wiko Global Sasu Wiko Tommy2',
#  'Samsung Galaxy Note 3 (Sm-N9005)',
#  'Lenovo Lc12988845',
#  'Tcl Communicatio. Pixi 4 6 3G Android',
#  'Samsung Galaxy Core Prime (Sm-G361F)',
#  'Htc Desire 825',
#  'Lenovo Moto G (3Rd Gen)',
#  'Hmd Global Oy Nokia 6 Ss',
#  'Rim Blackberry 9320',
#  'Htc Desire 626',
#  'Maysun Info Tech. M4028',
#  'Asustek Asus Zenfone2 Ze551Ml',
#  'Huawei E5577 E5577C',
#  'Samsung Gt-I9105P',
#  'Xiaomi Communica. M1806E7Tg',
#  'Spa Condor Elect. C6+',
#  'Samsung Galaxy Alpha (Sm-G850X)',
#  'Shenzhen Fortune. X8610',
#  'Rim Blackberry Rhd131Lw (Str100-1)',
#  'Lg Lg-D315',
#  'Wiko Global Sasu Wiko Sunny2',
#  'Shenzhen Leagoo. Leagoo M9 Pro',
#  'Asustek Asus Zenfone 3 Max Zc520Tl',
#  'Microsoft Mobile. Rm-1127 Microsoft Lumia 550',
#  'Samsung Galaxy J2',
#  'Crosscall Action-X3',
#  'Nokia Lumia 635 Rm-974',
#  'Huawei Sla-L22',
#  'Yota Devices Yotaphone2',
#  'Samsung Galaxy Mega Duos (Gt-I9152)',
#  'Lg L80',
#  'Huawei Nova',
#  'Lenovo Bl12416045',
#  'Wiko Global Sasu Wiko Rainbow Jam',
#  'Tcl Communicatio. U5',
#  'Lg-M200N',
#  'Huawei Honor 7S',
#  'Hmd Global Oy Nokia 7 Plus Ds',
#  'Tcl Communicatio. Alcatel Onetouch Pixi 3 (4.5)',
#  'Samsung Galaxy Tab A (Sm-T555)',
#  'Oneplus Technolo. Oneplus 5',
#  'Xiaomi Communica. Redmi 4X',
#  'Electro Depot Fr. W55Hd',
#  'Asustek Asus Zenfone4 Max Zc520Kl',
#  'Source (Hk) Ltd J-Max Zara-Zara',
#  'Lg-X210Ds',
#  'Oppo A37Fw',
#  'Samsung Galaxy Note 5 (Sm-N920X)',
#  'Xiaomi Communica. Mi A1',
#  'Lenovo Moto E Plus (4Th Gen) Go12071045',
#  'Lg-H815',
#  'Huawei E5776S-32',
#  'Logicom Sa Logicom Le Moov',
#  'Shenzhen Fortune. Nh001',
#  'Xiaomi Communica. Redmi 6',
#  'Huawei P10 Plus',
#  'Spa Condor Elect. P4',
#  'Oneplus Technolo. Oneplus 3',
#  'Sony Mobile Comm. Xperia E5',
#  'Lenovo Moto X Style',
#  'Htc Pl80100',
#  'Huawei Hma-L29',
#  'Huawei Nova 3E',
#  'Huawei Bln-Al30',
#  'Xiaomi Communica. Xiaomi Note',
#  'Huawei Honor 7A',
#  'Htc Desire 650',
#  'Samsung Galaxy J1 (Sm-J120X)',
#  'Xiaomi Communica. Redmi S2',
#  'Sony Mobile Comm. Pm-1150-Bv',
#  'Infocus Corporat. Infocus Vzh',
#  'Huawei Jmm-L22 Honor 6C Pro Honor 6C Pro',
#  'Spa Condor Elect. P8 Lite',
#  'Tcl Communicatio. Alcatel Onetouch Pixi 3 (3.5) 4009X',
#  'Huawei Cor-L29',
#  'Xiaomi Communica. Redmi Note5A',
#  'Sony Ericsson Mt27I - Xperia Sola',
#  'Tct Mobile Suzho. Alcatel Onetouch Pop2 4.5',
#  'Oneplus Technolo. Oneplus5T',
#  'Samsung Galaxy Trend (Gt-S7560)',
#  'Acer Liquid Zest Plus',
#  'Tcl Communicatio. Alcatel 3L 5034D',
#  'Hmd Global Oy Nokia 2 Ds',
#  'Xiaomi Communica. Mi A2',
#  'Wiko Global Sasu View2',
#  'Samsung Galaxy Note 8',
#  'Lg-K100Ds',
#  'Huawei Y3',
#  'Oneplus Technolo. Oneplus 3T',
#  'Htc Desire 620',
#  'Huawei Honor',
#  'Lenovo Za12074545',
#  'Apple iPhone 5C (A1456)',
#  'Wiko Global Sasu Wiko Sunset',
#  'Hmd Global Oy Nokia 6.1 Ds',
#  'Lenovo Moto G Play (4Th Gen) Ju12797645',
#  'Samsung Galaxy Core Prime (Sm-G360X)',
#  'Spa Condor Elect. Plume P6 Pro Lte',
#  'Apple iPhone 5 (A1428) A1428S',
#  'Sony Mobile Comm. Pm-1164-Bv',
#  'Lephone U Pro',
#  'Oneplus Technolo. Oneplus A3003',
#  'Sony Mobile Comm. Xperia Xz',
#  'Lenovo Moto X Play',
#  'Microsoft Mobile. Rm-1154 Microsoft Lumia 650 Dual Sim',
#  'Hmd Global Oy Nokia 5 Ds',
#  'Asustek Asus_Z00Ad',
#  'Samsung Galaxy Note 2 (Gt-N7105)',
#  'Nokia Lumia 925 Lumia 925',
#  'Sony Mobile Comm. Pm-1151-Bv',
#  'Apple iPad Air 2 (A1567)',
#  'Neel Enterprise Kolor Crosscall Odyssey',
#  'Htc 2Q5V100',
#  'Oppo Cph1837',
#  'Htc Desire 610',
#  'Htc Desire 820',
#  'Asustek Asus Zenfone 4 Ze554Kl',
#  'Wiko Global Sasu View Go',
#  'Archos Sa 50 Titanium 4G',
#  'Concox Informati. Gt06',
#  'Zte Blade A506 Blade A506 Dive 71 Orange Dive 71 D52 Lite',
#  'Wiko Global Sasu Wiko Harry',
#  'Wileyfox Europe. Wileyfox Swift 2',
#  'Logicom Sa L-Ite 400M',
#  'Asustek Asus Zc553Kl Zenfone 3 Max',
#  'Nokia Rm-1090 Lumia 535 Dual Sim Microsoft Lumia 535 Dual Sim',
#  'Lg G4',
#  'Samsung Galaxy J4 Core',
#  'Shenzhen Jeko Co. Blackview Bv8000 Pro',
#  'Asustek Asus Ze550Kl Zenfone2 Laser',
#  'Lenovo Moto G (5Th Gen S) D012081145',
#  'Samsung Sm-N7505',
#  'Nokia Lumia 635 Rm-975',
#  'Wiko Global Sasu Wiko Upulse Lite',
#  'Doro Ab Doro 8030 Doro 8028 Doro 8031 Doro 8030C Doro 8031C',
#  'Wiko Global Sasu Wiko Jerry',
#  'Samsung Galaxy S9 Sm-G960F',
#  'Lenovo Lenovo B Lenovo Vibe B',
#  'Xiaomi Communica. M1805D1Sg',
#  'Google Inc Pixel 3Xl',
#  'Microsoft Mobile. Microsoft Rm-1089 Microsoft Lumia 535',
#  'Shenzhen Xin Kin. V18H',
#  'Tcl Communicatio. Alcatel 3C',
#  'Apple iPad 4 (A1460)',
#  'Oppo Cph1821',
#  'Microsoft Mobile. Rm-1072 Lumia 640 Lte',
#  'Oppo Cph1723',
#  'Sony Mobile Comm. Xperia Z5',
#  'Tcl Communicatio. Alcatel Onetouch Pop 3 (5)',
#  'Wiko Global Sasu Wiko Wim Lite',
#  'Huawei Ascend Mate7',
#  'Sony Mobile Comm. Sony D2303 - Xperia M2',
#  'Kvd Internationa. Doogee X5 Max Pro',
#  'Xiaomi Communica. Redmi 5 Plus',
#  'China Trade Grou. Ed1',
#  'Huawei Aum-Al00',
#  'Htc 2Q5W100',
#  'Doro Ab Doro Liberto 825',
#  'Samsung Galaxy A5 Sm-A520F Ds',
#  'Microsoft Mobile. Rm-1152 Microsoft Lumia 650',
#  'Huawei Y635',
#  'Crosscall Core-X3',
#  'Hmd Global Oy Nokia 8110 4G Ds',
#  'Samsung Galaxy Note (Gt-N7000)',
#  'Lenovo P2 Ku12842445',
#  'Lenovo Moto E (4Th Gen)',
#  'Huawei Mate 10 Pro',
#  'Archos Sa Archos Sense 50X',
#  'Archos Sa Diamond S',
#  'Sony Mobile Comm. Xperia X Compact',
#  'Huawei Vog-L29',
#  'Samsung Galaxy Wave 2 (Gt-S8530)',
#  'Lg-K430Ds',
#  'Asustek Asus Zenfone 3 Deluxe Zs570Kl',
#  'Huawei B618S-22D',
#  'Kvd Internationa. Doogee X10',
#  'Wiko Global Sasu Wiko U Feel Lite',
#  'Microsoft Mobile. Rm-1065 Lumia 640 Xl Lte Dual Sim',
#  'Oneplus Technolo. One A1001 Oneplus A0001 One A0001',
#  'Hem Easy',
#  'Hmd Global Oy Ta-1080',
#  'Kapsys Smartvision2 Smartconnect2',
#  'Spa Condor Elect. Plume H1',
#  'Rim Blackberry 9360',
#  'Crosscall Trekker-X3',
#  'Samsung Galaxy Note 9',
#  'Shenzhen Fortune. Ss5804G',
#  'Wiko Global Sasu Wiko Rainbow 4G',
#  'Oppo Pbam00',
#  'Wiko Global Sasu Wiko View Xl',
#  'Vplus Communicat. Vplus V5001',
#  'Sony Mobile Comm. Xperia Xa Ultra',
#  'Intermec Technol. Series 70 (Cn70 1000Cp01U) (Cn70E 1000Cp02U) (Ck70 1001Cp01U)',
#  'Qingdao Hisense. Hisense F23',
#  'Sony Mobile Comm. Xperia E3',
#  'Nokia Rm-1045 Lumia 930 Nokia 930',
#  'Lg Lg-D620Fr',
#  'Huawei E5786S-32A Huawei E5786Bs-32A',
#  'Sony Mobile Comm. Xperia Xz Premium',
#  'Meizu Technology. Meizu U20',
#  'Nokia 1661-2 1661',
#  'Samsung Galaxy S8 Edge (Sm-G955U)',
#  'Archos Sa Archos 40 Helium',
#  'Samsung Galaxy J3 (Sm-J330G Ds)',
#  'Samsung Galaxy J7 Prime Duos (Sm-G610F Ds)',
#  'Lg G3',
#  'Huawei Jkm-Lx1',
#  'Lenovo Al12492145',
#  'Nokia Rm-984 Lumia 830 Nokia 830',
#  'Lenovo Moto G (5Th Gen) Da12985045',
#  'Huawei Hwi-Al00',
#  'Tcl Communicatio. A7 Xl',
#  'Microsoft Mobile. Rm-1085 Microsoft Lumia 950 Xl',
#  'Huawei Frd-L19',
#  'Oppo A1601',
#  'Xiaomi Communica. Redmi Note6 Pro',
#  'Vivo Mobile Comm. Vivo Vivo 1718',
#  'Asustek Asus Zs620Kl Zenfone 5Z',
#  'Huawei P8',
#  'Xiaomi Communica. A7',
#  'Meizu Technology. M3 Note',
#  'Xiaomi Communica. Redmi 4A',
#  'Samsung 2018 Galaxy J4',
#  'Xiaomi Communica. Pocophone F1',
#  'Samsung Gt-I8730',
#  'Tinno Mobile Tec. Tinno S9111',
#  'Shenzhen Jeko Co. Blackview S8',
#  'Lenovo Al12415545',
#  'Asustek Asus Zb552Kl Zenfone Go',
#  'Spa Condor Elect. Allure M3',
#  'Asustek Zenfone Max Pro(M1)',
#  'Sony Mobile Comm. Xperia L2',
#  'Xiaomi Communica. Redmi Note4X',
#  'Fairphone B.V Fairphone 2',
#  'Sony Ericsson Lt18I',
#  'Sony Mobile Comm. Pm-1190-Bv',
#  'Asustek Zenfone 4 Selfie Pro',
#  'Tcl Communicatio. Blackberry Bbb100-2',
#  'Zte Mf626',
#  'Samsung Galaxy J7 (Sm-J701F Ds)',
#  'Samsung Galaxy C5 (Sm-C500X)',
#  'Doke Communicati. Blackview Bv6800 Pro',
#  'Sony Mobile Comm. Xperia E4G Dual',
#  'Xiaomi Communica. M1902F1G',
#  'Asustek Asus Zenfone Zoom S Ze553Kl',
#  'Shenzhen Jeko Co. Blackview Bv7000',
#  'Oppo Cph1893',
#  'Gemalto M2M Gmbh Cinterion Ehs6',
#  'Tcl Communicatio. Alcatel Onetouch Idol3 (5.5)',
#  'Microsoft Mobile. Rm-1011 Nokia 225 Dual Sim',
#  'Oppo Cph1609',
#  'Apple iPhone 5C (A1529)',
#  'Lemobile Informa. Lex651',
#  'Huawei Tbd',
#  'Hmd Global Oy Nokia 6 Ds',
#  'Sony Mobile Comm. Sony Xperia Z (C6603)',
#  'Xiaomi Communica. Mi A2 Lite',
#  'Tcl Communicatio. Blackberry Bba100-2',
#  'Huawei Nova 2I Huawei Mate 10 Lite',
#  'Lenovo Moto E (2Nd Gen) With 4G Lte St12406045',
#  'Oppo Cph1903',
#  'Huawei Chc-U01',
#  'Samsung Galaxy J1 (Sm-J100X)',
#  'Wiko Global Sasu Wiko U Feel Prime',
#  'Xiaomi Communica. Mi Mix2S',
#  'Qingdao Hisense. Cmb510',
#  'Samsung Gt-I5800',
#  'Archos Sa 55 Diamond Selfie ( Lite)',
#  'Shenzhen Boway E. Boway Boway U11',
#  'Qingdao Hisense. Hisense L675',
#  'Samsung Galaxy A7 Sm-A720F Ds',
#  'Logicom Sa L-Egant One',
#  'Tct Mobile Suzho. Alcatel Onetouch Idol 3 (4.7)',
#  'Nokia 625 Lumia 625',
#  'Samsung Gt-I9003',
#  'Archos Sa 55 Helium (Ultra)',
#  'Rainbow Communic. C45',
#  'Apple iPhone Xs (A1920)',
#  'Wiko Global Sasu Wiko Highway 4G',
#  'Lg K10',
#  'Ddm Brands Llc Andy 4.5El Lte',
#  'Rim Blackberry Sqc100-4 Rhg161Lw',
#  'Shenzhen Jeko Co. Blackview Bv6000',
#  'Zte Blade V8 Lite Blade V8 Lite Zte Blade V8 Se',
#  'Lenovo Moto G With 4G Motorola M0Fa8',
#  'Lg-K100',
#  'Samsung Galaxy J2 Prime (Sm-G532)',
#  'Logicom Sa Le Lift',
#  'Xiaomi Communica. Redmi 5',
#  'Sony Mobile Comm. Xperia Xz2 Compact',
#  'Tct Mobile Suzho. One Touch Idol S',
#  'Sony Mobile Comm. Xperia M4 Aqua Dual',
#  'Tcl Communicatio. Alcatel Pixi 4 5045D',
#  'Samsung Galaxy Ace 3 (Gt-S7275)',
#  'Dg Homtom Group. Homtom Ht16',
#  'Shenzhen Leagoo. Leagoo S8',
#  'Htc Desire 816',
#  'Logicom Sa Id Bot 54',
#  'Huawei Was-Al00',
#  'Rim Blackberry 8520',
#  'Logicom Sa L-Ement 403',
#  'Archos Sa 50 Platinum 4G',
#  'Wiko Global Sasu Wiko Pulp 4G',
#  'Huawei Vns-Al00',
#  'Archos Sa 55 Cobalt + Bush Spira B3 5.5',
#  'Huawei Maya',
#  'Htc 2Q55100',
#  'Wiko Global Sasu Wiko Rainbow Up 4G',
#  'Hmd Global Oy Nokia 3',
#  'Shenzhen Huanuo. B2803',
#  'Lg Nexus 5',
#  'Asustek Asus Zenfone 3 Ze552Kl',
#  'Htc One (M8)',
#  'Ddm Brands Llc Andy 5El Lte',
#  'Tcl Communicatio. B-Athena',
#  'Samsung Galaxy S4 Advance (Gt-I9506)',
#  'Orbita Telecom L. Konrow',
#  'Lg G4C',
#  'Hong Kong Frog I. A10',
#  'Lenovo Moto X Play Lx12506245',
#  'Kiwip Technologi. Montre Telephone Connectee Kiwip',
#  'Huawei E5220S-2',
#  'Kook (Hong Kong). Teeno T600',
#  'Yota Devices Yota Y3',
#  'Huawei Honor 6',
#  'Lenovo Moto Z Ve12657645',
#  'Lenovo Moto G (3Rd Gen) Ca12459445',
#  'Samsung Gt-S6790N',
#  'Sony Mobile Comm. Xperia M5 Dual',
#  'Sfr Altice S61',
#  'Lg Lm-X410Eow',
#  'Asustek Asus Za550Kl Zenfone Max M1',
#  'Huawei Fig-Al10',
#  'Zte Blade V7 Lite Blade V6 Plus Zte Blitz',
#  'Qingdao Hisense. Hisense F31',
#  'Huawei Mate 8',
#  'Samsung Galaxy S8 (Sm-G950U)',
#  'Lenovo Nexus 6 Valocia',
#  'Huawei Plk-L01',
#  'Kenxinda V7',
#  'Huawei Fig-Al00',
#  'Huawei G535-L11',
#  'Lg Lg-H635',
#  'Sfr Starxtrem7',
#  'Huawei Y9 2019',
#  'Asustek Asus Zenfone2 Laser Ze601Kl',
#  'Htc 2Pya210',
#  'Huawei G8 Huawei Gx8 Huawei G7 Plus',
#  'Huawei Y6Ii',
#  'Hmd Global Oy Nokia 1 Ds',
#  'Qingdao Hisense. Hisense C20',
#  'Samsung Galaxy S3 (Gt-I9300)',
#  'Oppo A33F',
#  'Tcl Communicatio. Alcatel Pixi 4 (4) 4034X',
#  'Xiaomi Communica. Mi Mix2',
#  'Samsung Galaxy J5',
#  'Qingdao Hisense. Hisense F17 Pro',
#  'Lenovo Moto G Plus (4Th Gen) Af12802845',
#  'Huawei Y3Ii',
#  'Samsung Galaxy A9 2018',
#  'Apple iPhone Xr (A2108)',
#  'Lenovo K Pro',
#  'Lenovo Moto G (5Th Gen) Da12984545',
#  'Huawei Jat-L29',
#  'Samsung Galaxy S9+',
#  'Microsoft Mobile. Rm-1116 Microsoft Lumia 950 Xl',
#  'Mundo Reader S.L. Aquaris U2 16+2',
#  'Umi Network Tech. Z2',
#  'Microsoft Mobile. Rm-1104 Microsoft Lumia 950',
#  'Huawei P8Max',
#  'Lg Lg-E610',
#  'Logicom Sa Le Up',
#  'Asustek Asus Zc521Tl Zenfone 3S Max',
#  'Wiko Global Sasu View2 Pro',
#  'Nubia Technology. Nx569H',
#  'Lenovo K6',
#  'Avenir Telecom Pm550S',
#  'Lg-K350Nds',
#  'Wiko Global Sasu Rainbow Jam 4G',
#  'Asustek Asus Zenfone Live Zb501Kl',
#  'Apple iPhone 7 Plus (A1785)',
#  'Samsung Gt-B3210C',
#  'Crosscall Action-X3 Pro',
#  'Wiko Global Sasu Wiko Highway Pure',
#  'Shanghai Chengyu. Pp6000',
#  'Tcl Communicatio. Pixi 4 6 4G Android',
#  'Sony Mobile Comm. Xperia Xz1 Compact',
#  'Oppo Cph1729',
#  'Sony Mobile Comm. Pm-1181-Bv',
#  'Xiaomi Communica. Redmi 5Plus',
#  'Logicom Sa Logicom B Bot 50',
#  'Lg-H870S',
#  'Tcl Communicatio. A3 Xl',
#  'Sony Mobile Comm. Xperia Xa1 Plus',
#  'Huawei Nova 3I Huawei P Smart+',
#  'Htc One Mini 2',
#  'Lg-X210',
#  'Spa Condor Elect. Allure M2',
#  'Rim Blackberry Passport Sqw100-1 Rgy181Lw',
#  'Oneplus Technolo. One E1003',
#  'Archos Sa Core 50 4G(L)',
#  'Meizu Technology. Pro 7',
#  'Microsoft Mobile. Nokia Lumia 530 Dual Sim Rm-1019',
#  'Hmd Global Oy Nokia 8 Ss',
#  'Htc Desire 10 Lifestyle',
#  'Lenovo Moto X (2Nd Generation) X112360445',
#  'Xiaomi Communica. M1808D2Tg',
#  'Lg X Power2',
#  'Hmd Global Oy Ta-1109',
#  'Sony Mobile Comm. Sony Xperia Z1 Compact (D5503)',
#  'Microsoft Mobile. Rm-1118 Microsoft Lumia 950',
#  'Hmd Global Oy Nokia 3 Ds',
#  'Oppo R11S',
#  'Samsung Galaxy Mobile (E.G. A3Lschi535)',
#  'Sfr Starxtrem5',
#  'Qingdao Hisense. S41',
#  'Tcl Communicatio. Nura 2',
#  'Huawei Ascend Y550',
#  'Asustek Asus Zenfone2 Laser Ze600Kl',
#  'Bullitt Group Li. S60',
#  'Doro Ab Doro 8040',
#  'Huawei Was-Tl10',
#  'Huawei Honor 8 Lite',
#  'Lenovo Lenovo A6020A40',
#  'Kvd Internationa. Doogee X60L',
#  'Logicom Sa L-Ement 505 T580',
#  'Haier L55',
#  'Tcl Communicatio. Alcatel 1',
#  'Htc Desire 820G Plus Dual Sim',
#  'Meizu Technology. M5C',
#  'Logicom Sa L-Ite 552',
#  'Shenzhen New Cha. Cb358',
#  'Qingdao Hisense. Hisense L830',
#  'Lg-H811',
#  'Spa Condor Elect. Plume L1 Plus',
#  'Asustek Asus Zenfone 2 Laser Ze500Kl',
#  'Huawei Ale-Ul00',
#  'Zte Racer Iii Mini Zte Switch X1 Bouygues Telecom Bs 402 Blade Q Mini Zte Blade G Pro',
#  'Lg-H850',
#  'Leagoo Intl Co. . Leagoo T5',
#  'Zte Blade A2 Plus Zte Blade A610 Plus',
#  'Samsung Galaxy A6 Duos (Sm-A605G Ds)',
#  'Huawei Honor 6C Dig-L21Hn',
#  'Acer M310',
#  'Asustek Asus Zenfone Max Pro Zb631Kl',
#  'Fully Holdings (. C8 4G',
#  'Logicom Sa Logicom Vr Bot 552+',
#  'Archos Sa 50F Neon',
#  'Tct Mobile Suzho. Alcatel One Touch Pop C1 Alcatel One Touch Pop C1 Alcatel One Touch Pixi2',
#  'Sony Mobile Comm. Pm-0951-Bv',
#  'Doro Ab Doro 6530 Doro 6531',
#  'Huawei Y5 2017',
#  'A-Link Telecom I. Cubot X18 Plus',
#  'Wiko Global Sasu View Lite',
#  'Nokia 920.1 Lumia 920',
#  'Doro Ab Doro 6520 Doro 6521',
#  'Tcl Communicatio. Alcatel A3',
#  'Sony Mobile Comm. Xperia Z5 Premium',
#  'Tecno Telecom (H. Phantom6 Plus',
#  'Apple iPhone 3Gs (A1303)',
#  'Wiko Global Sasu Wiko Tommy2 Plus',
#  'Lenovo Moto G (4Th Gen) Af12802745',
#  'Lenovo Moto X (4Th Gen) Ib12266545',
#  'Netgear Inc Netgear Ac785S-100',
#  'Sony Mobile Comm. Pm-0953-Bv',
#  'Huawei Y6 Pro',
#  'Logicom Sa Le Must',
#  'Alif Communicati. Pulian Cm84',
#  'Rim Blackberry Stl100-2 Z10 Rfh121Lw',
#  'Logicom Sa Le Hello',
#  'Rim Blackberry Sqc100-1 Rhh151Lw',
#  'Lg-K420N',
#  'Asustek Asus Zenfone 5 Lite Zc600Kl',
#  'Htc One A9',
#  'Nokia Rm-941 Nokia 625 Lumia 625',
#  'Maysun Info Tech. M5026',
#  'Huawei Dli-Al10',
#  'Qingdao Hisense. Starxtrem 6',
#  'Qingdao Hisense. Hisense F24',
#  'Lg-M160',
#  'Lemobile Informa. Lex622',
#  'Samsung Galaxy A7 (Sm-A730F)',
#  'Shenzhen Jsr Tec. Innos K502',
#  'Gotron (Hk) Elec. Gemini',
#  'Neel Enterprise Kolor Crosscall Trekker-X1',
#  'Tecno Telecom (H. C9',
#  'Xiaomi Communica. B3',
#  'Oneplus Technolo. One A2003',
#  'Shenzhen Jeko Co. Blackview A20',
#  'Asustek Asus Zenfone Max Zc550Kl',
#  'Acer Liquid Z220',
#  'Archos Sa Access 45 4G',
#  'Sony Mobile Comm. Sony St26I',
#  'Lg Lm-G710Em',
#  'Shenzhen Xin Kin. V1600',
#  'Asustek Zenfone Max Zc550Kl',
#  'Huawei Bkl-Tl10',
#  'Lenovo Moto C Plus Lc12988845',
#  'Doro Ab Doro Phoneeasy 632',
#  'Huawei Stf-Al00',
#  'Vivo Mobile Comm. Vivo Vivo X21A',
#  'Tp-Link Technolo. Archer Mr200',
#  'Huawei Y6',
#  'Logicom Sa Le Smooth',
#  'Ecom Instruments. Ecom Mobile Safety Ex-Handy 209',
#  'Xiaomi Communica. M1804C3Dg',
#  'Sdt Electronica Startrail 8',
#  'Haier G50 L54',
#  'Qingdao Hisense. Hisense F20',
#  'Huawei Jsn-Al00A',
#  'Huawei Lnd-L29',
#  'Sony Mobile Comm. Xperia M5',
#  'Zte Axon 6S Zte Axon 7 Axon 7',
#  'Lenovo Moto Z Play (2Nd Gen) Ho12005845',
#  'Wiko Global Sasu Wiko Kite',
#  'Samsung Sm-G110H',
#  'Kvd Internationa. Doogee S30',
#  'Infinix Technolo. Infinix Surf Bravo',
#  'Hmd Global Oy Nokia 5 Ss',
#  'Hmd Global Oy Ta-1063 Ds',
#  'Nubia Technology. Z17S',
#  'Huawei Ascend Y330',
#  'Huawei Nova 2',
#  'Samsung Galaxy J7 (Sm-J701F)',
#  'Sierra Wireless Mc8355',
#  'Umi Network Tech. Umidigi Z1 Pro',
#  'Modelabs Clap Plus 2',
#  'Wiko Global Sasu Wiko Jerry Max',
#  'Tcl Communicatio. B-Luna',
#  'Htc One M9',
#  'Huawei P9 Plus',
#  'Lenovo Moto Z Force (2Nd Gen) Ge12072245',
#  'Tcl Communicatio. Alcatel A5 Led Alcatel A5',
#  'Casper Bilgisaya. Via M1',
#  'Htc U Play',
#  'Asustek Asus Zenfone Live Zb553Kl',
#  'Xiaomi Communica. Mi Max2',
#  'Oppo Cph1877',
#  'Archos Sa 50B Cobalt (Lite)',
#  'Lg L Bello',
#  'A-Link Telecom I. Cubot A5',
#  'Tct Mobile Suzho. Alcatel Onetouch Pop S7',
#  'Hmd Global Oy Nokia 2',
#  'Samsung Galaxy J8 2018',
#  'Google Inc G011C',
#  'Acer Liquid Z530',
#  'Tp-Link Technolo. C5A',
#  'Spa Condor Elect. Allure M1 Plus',
#  'Dg Homtom Group. Homtom H50',
#  'Xiaomi Communica. Mi Max3',
#  'Asustek Asus Zb570Tl',
#  'Infinix Technolo. Hot 6',
#  'Huawei Y6 Pro 2017 Huawei P9 Lite Mini',
#  'Lenovo D012064645',
#  'Huawei P Smart',
#  'Huawei Y7',
#  'Meizu Technology. Mx6',
#  'Samsung Galaxy J5 Prime Dual-Sim (Sm-G570F Ds)',
#  'Huawei Bln-Tl10',
#  'Sony Mobile Comm. Sony C5303 -Xperia Sp',
#  'Htc U11',
#  'Shenzhen Diadem. Liquid Z6',
#  'Lg Lg-P700',
#  'Xiaomi Communica. M1805E10A',
#  'Htc Desire X',
#  'Oneplus Technolo. Oneplus A3000',
#  'Xiaomi Communica. Mi 5X',
#  'Crosscall Trekker-X4',
#  'Dg Homtom Group. Homtom Ht3',
#  'Lenovo Moto G Plus (5Th Gen) Co128983645',
#  'Lenovo Ro12524245',
#  'Tct Mobile Suzho. Alcatel One Touch 6030X',
#  'Tp-Link Technolo. X1 Lite',
#  'Oppo F1F',
#  'Apple iPhone 8 Plus (A1898)',
#  'Samsung Galaxy Note 8 (Sm-N9500)',
#  'Huawei Vns-Dl00',
#  'Tcl Communicatio. Pop 4+',
#  'A-Link Telecom I. Cubot Power',
#  'Wiko Global Sasu Wiko View Prime',
#  'A-Link Telecom I. Cubot Note Plus',
#  'Lenovo Xt1772',
#  'Asustek Zc550Kl Zenfone Max',
#  'Xiaomi Communica. M1901F7G',
#  'Kvd Internationa. Doogee Mix',
#  'Asustek Asus Ze500Kl Zenfone 2 Lazer',
#  'Lemobile Informa. Le X820',
#  'Sony Mobile Comm. Sony Xperia Z1 (C6903)',
#  'Samsung Sm-T819',
#  'Huawei Dub-Lx1',
#  'Huawei B525S-65A',
#  'Apple iPhone 6S Plus (A1699)',
#  'Huawei Me909S-120',
#  'Shenzhen Jeko Co. Blackview Bv9000 Pro',
#  'Apple iPhone Xs Max (A2104)',
#  'Huawei Stf-Tl10',
#  'Wiko Global Sasu Lenny2',
#  'Microsoft Mobile. Nokia Lumia 530 Rm-1017',
#  'Quartel Infotech. Maximus M84',
#  'Tct Mobile Suzho. Alcatel One Touch Y580D',
#  'Shenzhen Fortune. M-Ppas6',
#  'Wiko Global Sasu Wiko Ridge 4G',
#  'Hongkong Ipro Te. Ipro I9350 I9400 S3 Wave 3.5 Wave 4.0',
#  'Shenzhen Guowei. V6304',
#  'Dynamic Tech Hol. D-Mobile I3 I5 I7 I8 I9',
#  'Shenzhen Malata Liger 81G Smb-E1002 Smb-E8001',
#  'Simcom Wireless. Sim800H',
#  'Tecno Telecom (H. It1506',
#  'Apple iPad Pro 12.9 (A1671)',
#  'Nokia 620 Lumia 620 Nokia 620',
#  'Infinix Technolo. Infinix Hot Note',
#  'Lg Optimus L5 Ii',
#  'Samsung Galaxy Tab A (Sm-T585)',
#  'D-Link Corporati. Dwr-921',
#  'Samsung Galaxy J1 Ace (Sm-J111X)',
#  'Sony Mobile Comm. Xperia Z2',
#  'Apple iPad Mini (A1455)',
#  'Nokia Rm-998 525 Lumia 525 Nokia 525',
#  'Rim 8520',
#  'Haier Hw-W717 Hw-W816 Hw-W870',
#  'Kazam Mobile Lim. Kazam Trooper 451',
#  'Xiaomi Communica. Redmi Note 2',
#  'Huawei U8815',
#  'Samsung Sm-G386F',
#  'Nokia Rm-1091 Lumia 535 Microsoft Lumia 535',
#  'Nubia Technology. Z17 Mini',
#  'Xiaomi Communica. Redmi 5A',
#  'Samsung Galaxy Mini (Gt-S5570)',
#  'Lidaxin Technolo. My81',
#  'Logicom Sa L-Ement 553',
#  'Microsoft Mobile. Nokia Rm-1034 Microsoft Lumia 532',
#  'Nokia X',
#  'Acer Liquid M220',
#  'Sony Ericsson U20I (Aad-3880072-Bv)',
#  'M S Soha Enterp. Qphone Q70',
#  'Ecom Instruments. Ecom Mobile Safety Smart-Ex 201',
#  'Archos Sa Access 50 4G',
#  'Ddm Brands Llc Yezz Andy A6M',
#  'Concox Informati. Gt06E Gt06F Gv20',
#  'Samsung Galaxy Tab S2 (Sm-T719)',
#  'Zte Blade V8 Blade V8',
#  'Huawei B315S-22',
#  'Samsung Gt-S5660',
#  'Nokia Rm-914 520 Lumia 520 Nokia 520',
#  'Lenovo Moto G',
#  'Lenovo Lenovo A588T',
#  'Huawei B593S-12',
#  'Gemalto M2M Gmbh Cinterion Wireless Module Phs8-P',
#  'Nokia Rm-1019 Lumia 530 Dual Sim',
#  'Quanta 1Kg',
#  'Cisco Systems In. Cisco Mc7304',
#  'Tp-Link Technolo. Tp-Link M7350',
#  'Samsung Galaxy Tab A (Sm-T285)',
#  'Hmd Global Oy Ta-1095',
#  'Microsoft Mobile. Microsoft Rm-1071 Microsoft Lumia 435',
#  'Lg-K120E',
#  'Sfr Altice S11',
#  'Archos Sa Archos 50C Platinum',
#  'Logicom Sa L-Ement 400',
#  'Sony Mobile Comm. Sony St21I Xperia Tipo',
#  'Apple iPad 3 (A1430)',
#  'Zyxel Communicat. Lte7460',
#  'Adar Stanley Mobile S231',
#  'Crosscall Odyssey-S1',
#  'Ddm Brands Llc Andy 4Ei2',
#  'Wiko Global Sasu Wiko Lenny',
#  'Samsung Galaxy J4+',
#  'Lg K10 2017',
#  'Asustek Wireless-Ac1200 Lte Router',
#  'Apple iPad (A1823)',
#  'Compal Electroni. Cat B15Q',
#  'Nokia Rm-941 625 Lumia 625',
#  'Topwell Technolo. Topwell M318A',
#  'Wiko Global Sasu Wiko Goa',
#  'Samsung Gt-I5500',
#  'Zyxel Communicat. Sbg3600',
#  'Samsung Gt-S5280',
#  'Wistron M18Qw',
#  'Telit Ul865-Eur',
#  'Haier W826',
#  'Sony Mobile Comm. Sony D2105',
#  'Huawei E3372',
#  'Itel Technology. S31',
#  'Nokia Rm-976 Lumia 630',
#  'Samsung Galaxy S4 (Gt-I9500)',
#  'Lenovo Moto G (2Nd Generation) Xt1068 Indr000145',
#  'Apple iPad Pro 9.7 (A1674)',
#  'Apple iPhone 8 Plus (A1899)',
#  'Kapsys Smartvision Kapsys Smartvision By Kapsys Smartconnect',
#  'Gemalto M2M Gmbh Cinterion Bgs3',
#  'Apple iPad 2 (A1396)',
#  'Samsung Gt-S5690',
#  'Huawei Evr-L29',
#  'Lg Leon',
#  'Archos Sa Archos 45B Helium 50B Helium 50C Helium 50D Helium 50 Diamond',
#  'Nokia 820.1 Lumia 820',
#  ...]

# %% [markdown]
# ### Cleaning

# %% [markdown]
# `#` Identified issues

# %% [markdown]
# 1. Some columns have inappropriate datatypes (IMSI, IMEI)
#
# 2. Columns with missing values needs to be filled
#
# 3. duplicate columns like `Dur. (ms).1` & `Dur. (ms)`
#
# 4. Column names should be formatted to be uniform (all lower case & snake_casing)
#
# 5. values of columns headest_types and headset_manufacturers shoul have uniform formatting

# %% [markdown]
# > First let's make a copy of the original data

# %%
clean_data = data.copy()

# %% [markdown]
# `#` issue1
#
# > convert columns [IMSI, IMEI,  MSISDN/Number] from number type to object/string type

# %%
clean_data.IMEI = clean_data.IMEI.astype('object')
clean_data.IMSI = clean_data.IMSI.astype('object')
clean_data['MSISDN/Number'] = clean_data['MSISDN/Number'].astype('object')

# %% [markdown]
# > Test

# %%
test1 = clean_data [['IMSI','IMEI','MSISDN/Number']]
test1.dtypes
# Out:
# IMSI             object
# IMEI             object
# MSISDN/Number    object
# dtype: object

# %% [markdown]
# `#` issue2
#
# - Fill missing values in numeric columns with mean
#
# - Fill missing vlaues in categorical columns with mode
#
#
# _we have establised that our outlier values are fewer than the normal values in these columns_

# %% [markdown]
# 1. numeric

# %%
clean_data[numeric_data.columns]=clean_data[numeric_data.columns].apply(lambda x: x.fillna(x.mean()),axis=0)

# %% [markdown]
# >test

# %%
clean_data.columns[clean_data.isnull().any()].tolist()
# Out:
# ['Start',
#  'End',
#  'IMSI',
#  'MSISDN/Number',
#  'IMEI',
#  'Last Location Name',
#  'Handset Manufacturer',
#  'Handset Type']

# %%
clean_data.columns[clean_data.isna().any()].tolist()
# Out:
# ['Start',
#  'End',
#  'IMSI',
#  'MSISDN/Number',
#  'IMEI',
#  'Last Location Name',
#  'Handset Manufacturer',
#  'Handset Type']

# %% [markdown]
# None of our numeric columns have Null or NaN values

# %% [markdown]
# 2. Categorical/datetime columns

# %%
categ_data = clean_data.columns[clean_data.isna().any()].tolist()

# %%
clean_data[categ_data].dtypes
# Out:
# Start                   datetime64[ns]
# End                     datetime64[ns]
# IMSI                            object
# MSISDN/Number                   object
# IMEI                            object
# Last Location Name              object
# Handset Manufacturer            object
# Handset Type                    object
# dtype: object

# %%
clean_data[categ_data]=clean_data[categ_data].apply(lambda x: x.fillna(x.mode()[0]),axis=0)

# %% [markdown]
# > Test

# %%
clean_data.columns[clean_data.isna().any()].tolist()
# Out:
# []

# %% [markdown]
# #### We have no more null columns in our dataset

# %% [markdown]
# `#` issue3

# %%
clean_data.drop('Dur. (ms).1', axis=1, inplace=True)

# %% [markdown]
# test

# %%
'Dur. (ms).1' in clean_data.columns.to_list()
# Out:
# False

# %% [markdown]
# `#` issue 4

# %%
cols = clean_data.columns.to_list()

# %%
clean_data.rename(columns= lambda x : x.lower().replace(' ', '_').replace('/', '_').replace(')', '_').replace('.', '_').replace('(', '_').strip() if x in cols else x, inplace=True)

# %% [markdown]
# test

# %%
clean_data.columns
# Out:
# Index(['bearer_id', 'start', 'start_ms', 'end', 'end_ms', 'dur___ms_', 'imsi',
#        'msisdn_number', 'imei', 'last_location_name', 'avg_rtt_dl__ms_',
#        'avg_rtt_ul__ms_', 'avg_bearer_tp_dl__kbps_', 'avg_bearer_tp_ul__kbps_',
#        'tcp_dl_retrans__vol__bytes_', 'tcp_ul_retrans__vol__bytes_',
#        'dl_tp_<_50_kbps__%_', '50_kbps_<_dl_tp_<_250_kbps__%_',
#        '250_kbps_<_dl_tp_<_1_mbps__%_', 'dl_tp_>_1_mbps__%_',
#        'ul_tp_<_10_kbps__%_', '10_kbps_<_ul_tp_<_50_kbps__%_',
#        '50_kbps_<_ul_tp_<_300_kbps__%_', 'ul_tp_>_300_kbps__%_',
#        'http_dl__bytes_', 'http_ul__bytes_', 'activity_duration_dl__ms_',
#        'activity_duration_ul__ms_', 'handset_manufacturer', 'handset_type',
#        'nb_of_sec_with_125000b_<_vol_dl',
#        'nb_of_sec_with_1250b_<_vol_ul_<_6250b',
#        'nb_of_sec_with_31250b_<_vol_dl_<_125000b',
#        'nb_of_sec_with_37500b_<_vol_ul',
#        'nb_of_sec_with_6250b_<_vol_dl_<_31250b',
#        'nb_of_sec_with_6250b_<_vol_ul_<_37500b',
#        'nb_of_sec_with_vol_dl_<_6250b', 'nb_of_sec_with_vol_ul_<_1250b',
#        'social_media_dl__bytes_', 'social_media_ul__bytes_',
#        'google_dl__bytes_', 'google_ul__bytes_', 'email_dl__bytes_',
#        'email_ul__bytes_', 'youtube_dl__bytes_', 'youtube_ul__bytes_',
#        'netflix_dl__bytes_', 'netflix_ul__bytes_', 'gaming_dl__bytes_',
#        'gaming_ul__bytes_', 'other_dl__bytes_', 'other_ul__bytes_',
#        'total_ul__bytes_', 'total_dl__bytes_'],
#       dtype='object')

# %% [markdown]
# `#` issue 5

# %%
clean_data.handset_manufacturer = clean_data.handset_manufacturer.apply(lambda x: x.lower().strip())

# %%
clean_data.handset_type = clean_data.handset_type.apply(lambda x: x.lower().strip())

# %% [markdown]
# test

# %%
'ZyXEL Communications Corp' in clean_data.handset_manufacturer
# Out:
# False

# %%
'ZyxeL Communications Corp' in clean_data.handset_manufacturer
# Out:
# False

# %% [markdown]
# #### Let's do a cursory inspection on our cleaned data

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 54 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   bearer_id                                 150001 non-null  object
#  1   start                                     150001 non-null  datetime64[ns]
#  2   start_ms                                  150001 non-null  float64
#  3   end                                       150001 non-null  datetime64[ns]
#  4   end_ms                                    150001 non-null  float64
#  5   dur___ms_                                 150001 non-null  float64
#  6   imsi                                      150001 non-null  float64
#  7   msisdn_number                             150001 non-null  float64
#  8   imei                                      150001 non-null  float64
#  9   last_location_name                        150001 non-null  object
#  10  avg_rtt_dl__ms_                           150001 non-null  float64
#  11  avg_rtt_ul__ms_                           150001 non-null  float64
#  12  avg_bearer_tp_dl__kbps_                   150001 non-null  float64
#  13  avg_bearer_tp_ul__kbps_                   150001 non-null  float64
#  14  tcp_dl_retrans__vol__bytes_               150001 non-null  float64
#  15  tcp_ul_retrans__vol__bytes_               150001 non-null  float64
#  16  dl_tp_<_50_kbps__%_                       150001 non-null  float64
#  17  50_kbps_<_dl_tp_<_250_kbps__%_            150001 non-null  float64
#  18  250_kbps_<_dl_tp_<_1_mbps__%_             150001 non-null  float64
#  19  dl_tp_>_1_mbps__%_                        150001 non-null  float64
#  20  ul_tp_<_10_kbps__%_                       150001 non-null  float64
#  21  10_kbps_<_ul_tp_<_50_kbps__%_             150001 non-null  float64
#  22  50_kbps_<_ul_tp_<_300_kbps__%_            150001 non-null  float64
#  23  ul_tp_>_300_kbps__%_                      150001 non-null  float64
#  24  http_dl__bytes_                           150001 non-null  float64
#  25  http_ul__bytes_                           150001 non-null  float64
#  26  activity_duration_dl__ms_                 150001 non-null  float64
#  27  activity_duration_ul__ms_                 150001 non-null  float64
#  28  handset_manufacturer                      150001 non-null  object
#  29  handset_type                              150001 non-null  object
#  30  nb_of_sec_with_125000b_<_vol_dl           150001 non-null  float64
#  31  nb_of_sec_with_1250b_<_vol_ul_<_6250b     150001 non-null  float64
#  32  nb_of_sec_with_31250b_<_vol_dl_<_125000b  150001 non-null  float64
#  33  nb_of_sec_with_37500b_<_vol_ul            150001 non-null  float64
#  34  nb_of_sec_with_6250b_<_vol_dl_<_31250b    150001 non-null  float64
#  35  nb_of_sec_with_6250b_<_vol_ul_<_37500b    150001 non-null  float64
#  36  nb_of_sec_with_vol_dl_<_6250b             150001 non-null  float64
#  37  nb_of_sec_with_vol_ul_<_1250b             150001 non-null  float64
#  38  social_media_dl__bytes_                   150001 non-null  float64
#  39  social_media_ul__bytes_                   150001 non-null  float64
#  40  google_dl__bytes_                         150001 non-null  float64
#  41  google_ul__bytes_                         150001 non-null  float64
#  42  email_dl__bytes_                          150001 non-null  float64
#  43  email_ul__bytes_                          150001 non-null  float64
#  44  youtube_dl__bytes_                        150001 non-null  float64
#  45  youtube_ul__bytes_                        150001 non-null  float64
#  46  netflix_dl__bytes_                        150001 non-null  float64
#  47  netflix_ul__bytes_                        150001 non-null  float64
#  48  gaming_dl__bytes_                         150001 non-null  float64
#  49  gaming_ul__bytes_                         150001 non-null  float64
#  50  other_dl__bytes_                          150001 non-null  float64
#  51  other_ul__bytes_                          150001 non-null  float64
#  52  total_ul__bytes_                          150001 non-null  float64
#  53  total_dl__bytes_                          150001 non-null  float64
# dtypes: datetime64[ns](2), float64(48), object(4)
# memory usage: 61.8+ MB

# %% [markdown]
#  - changed datatypes of certain columns were reversed during one of our operations.
#     This needs to be refixed

# %%
clean_data.imei = clean_data.imei.astype('object')
clean_data.imsi = clean_data.imsi.astype('object')
clean_data.msisdn_number = clean_data.msisdn_number.astype('object')

# %%
clean_data.dtypes
# Out:
# bearer_id                                           object
# start                                       datetime64[ns]
# start_ms                                           float64
# end                                         datetime64[ns]
# end_ms                                             float64
# dur___ms_                                          float64
# imsi                                                object
# msisdn_number                                       object
# imei                                                object
# last_location_name                                  object
# avg_rtt_dl__ms_                                    float64
# avg_rtt_ul__ms_                                    float64
# avg_bearer_tp_dl__kbps_                            float64
# avg_bearer_tp_ul__kbps_                            float64
# tcp_dl_retrans__vol__bytes_                        float64
# tcp_ul_retrans__vol__bytes_                        float64
# dl_tp_<_50_kbps__%_                                float64
# 50_kbps_<_dl_tp_<_250_kbps__%_                     float64
# 250_kbps_<_dl_tp_<_1_mbps__%_                      float64
# dl_tp_>_1_mbps__%_                                 float64
# ul_tp_<_10_kbps__%_                                float64
# 10_kbps_<_ul_tp_<_50_kbps__%_                      float64
# 50_kbps_<_ul_tp_<_300_kbps__%_                     float64
# ul_tp_>_300_kbps__%_                               float64
# http_dl__bytes_                                    float64
# http_ul__bytes_                                    float64
# activity_duration_dl__ms_                          float64
# activity_duration_ul__ms_                          float64
# handset_manufacturer                                object
# handset_type                                        object
# nb_of_sec_with_125000b_<_vol_dl                    float64
# nb_of_sec_with_1250b_<_vol_ul_<_6250b              float64
# nb_of_sec_with_31250b_<_vol_dl_<_125000b           float64
# nb_of_sec_with_37500b_<_vol_ul                     float64
# nb_of_sec_with_6250b_<_vol_dl_<_31250b             float64
# nb_of_sec_with_6250b_<_vol_ul_<_37500b             float64
# nb_of_sec_with_vol_dl_<_6250b                      float64
# nb_of_sec_with_vol_ul_<_1250b                      float64
# social_media_dl__bytes_                            float64
# social_media_ul__bytes_                            float64
# google_dl__bytes_                                  float64
# google_ul__bytes_                                  float64
# email_dl__bytes_                                   float64
# email_ul__bytes_                                   float64
# youtube_dl__bytes_                                 float64
# youtube_ul__bytes_                                 float64
# netflix_dl__bytes_                                 float64
# netflix_ul__bytes_                                 float64
# gaming_dl__bytes_                                  float64
# gaming_ul__bytes_                                  float64
# other_dl__bytes_                                   float64
# other_ul__bytes_                                   float64
# total_ul__bytes_                                   float64
# total_dl__bytes_                                   float64
# dtype: object

# %%
f'Null Values: {clean_data.isnull().any().sum()}'
# Out:
# 'Null Values: 0'

# %%
clean_data.shape
# Out:
# (150001, 54)

# %%
f'Any Duplicated columns: {clean_data.duplicated().any()}'
# Out:
# 'Any Duplicated columns: False'

# %% [markdown]
# #### Save the cleaned data to a csv file

# %%
new_path = 'datasets/cleaned'

# %%
clean_data.to_csv('../datasets/cleaned/cleanWk2_data.csv', index=False)
